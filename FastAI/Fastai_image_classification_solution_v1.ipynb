# %% [markdown]
# # Build your custom image classifier using FastAI and WML-CE

# %% [markdown]
# This notebook was copied and modified for this lab from this source https://github.com/fastai/course-v3
#
# Welcome to lesson 1! For those of you who are using a Jupyter Notebook for the first time, you can learn about this useful tool in a tutorial we prepared specially for you; click `File`->`Open` now and click `00_notebook_tutorial.ipynb`.
#
# In this lesson we will build our first image classifier from scratch, and see if we can achieve world-class results. Let's dive in!
#
# Every notebook starts with the following three lines; they ensure that any edits to libraries you make are reloaded here automatically, and also that any charts or images displayed are shown in this notebook.

# %%
# !pwd
# Out:
# /home/cecuser/5050/aicoc-ai-immersion/FastAI

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
import os
# For Using GPU's
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %% [markdown]
# ## About our Class Environment

# %% [markdown]
# We import all the necessary packages. We are going to work with the [fastai V1 library](http://www.fast.ai/2018/10/02/fastai-ai/) which sits on top of [Pytorch 1.3](https://hackernoon.com/pytorch-1-0-468332ba5163). The fastai library provides many useful functions that enable us to quickly and easily build neural networks and train our models.
#
# For this class, we are using WML-CE running in the Worldwide Client Experience Center Cloud, or CECC for short.  To access and environment, simply browse to this website and request a Power8 or Power9 environment.
#
# https://www.ibm.com/it-infrastructure/services/cecc-portal/web/Catalog
#
# * Note : To get PowerAI up and running we have a special setup script in our github repo ...
#
# https://github.ibm.com/vanstee/aicoc-ai-immersion/blob/master/FastAI/setup_fastai.sh

# %%
from fastai.vision import *
from fastai.metrics import error_rate
from pathlib import Path
import os

# utility print function
def nprint(mystring) :
    print("**{}** : {}".format(sys._getframe(1).f_code.co_name,mystring))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-3410fba3d1ea> in <module>
# ----> 1 from fastai.vision import *
#       2 from fastai.metrics import error_rate
#       3 from pathlib import Path
#       4 import os
#       5
#
# ModuleNotFoundError: No module named 'fastai'

# %% [markdown]
# ## Project Configuration
#
# This data structure below will hold all the settings for our class.  Its handy to have a simple dictionary contain all your project settings to keep organized.  We have include an override capability to these default settings so that you can customize your project.

# %%
def getconfig(cfg_in={},base_dir="."):
    cfg = {}
    cfg["bs"] = 16
    cfg["base_dir"]  = base_dir
    cfg["image_dir"] = base_dir + "/class_images"
    cfg["classes"] = ["cars","busses","trucks"]
    cfg["num_images"] = {"train":200,"valid":20,"test":20}
    cfg["d_partitions"] = list(cfg["num_images"].keys())                 
    cfg["jpeginfo"] =base_dir + "/jpeginfo"
   
    # overwrite configs if passed
    for (k,v) in cfg_in.items() :
        nprint("Overriding Config {}:{} with {}".format(k,cfg[k],v))
        cfg[k] = v
    return cfg

# bs = 16   # uncomment this line if you run out of memory even after clicking Kernel->Restart

# %% [markdown]
# ## Looking at the data

# %% [markdown]
# Here we are going to build our own dataset !!  Think of 3 categories you would like to classify images.  In this example, we will use
# * busses
# * trucks
# * cars
#
# We will use an open source tool called *googliser* to download our images from google images.
#
# For a Covid-19 based example you could make your classes something like
# * "people wearing masks"
# * "people posing street"

# %%
#################################################################################################
# @@ Students : Customize this cell with your custom classes for image classification
################################################################################################

# Overrides for lab

mycfg = {
    "classes":["people wearing masks","people posing street","people skateboarding","people on bikes"],  ## <<- CLASS Enter your search terms here 
    "d_partitions":["train"],
}

base_dir=!pwd
base_dir=base_dir[0]

print("Base project directory : {}".format(base_dir))
cfg=getconfig(mycfg, base_dir)
# Out:
# Base project directory : /home/cecuser/5050/aicoc-ai-immersion/FastAI
# **getconfig** : Overriding Config classes:['cars', 'busses', 'trucks'] with ['people wearing masks', 'people posing street', 'people skateboarding', 'people on bikes']
# **getconfig** : Overriding Config d_partitions:['train', 'valid', 'test'] with ['train']

# %% [markdown]
# ## Make Some Directories to hold our data
#
# FastAI is very flexible and help you label your image data in all sorts of ways.  You might have a bunch of images and a csv file with the labels.  You might have your images organized by folder with the folder name being the labels.
#
# To see all the supported methods check out this link..
# https://docs.fast.ai/vision.data.html#ImageDataBunch.from_folder
#
# For our class, we are going to organize our data by folder into something like this..
#
# ![image.png](attachment:image.png)

# %%
# Helpers to make directories
def class_folder_name(base,d_part,cls) :
    return base+"/"+d_part+"/"+ cls.replace(" ","_")

def makeDirIfNotExist(directory) :
    if not os.path.exists(directory):  
        nprint("Making directory {}".format(directory))
        os.makedirs(directory) 
    else :
        nprint("Directory {} already exists .. ".format(directory))

# Build directory hierarchy
#   [train|valid|test ]
#    -----------------> [class1 | class2 | class...]
for d_part in cfg["d_partitions"] :
    for cls in cfg["classes"] :
        directory=class_folder_name(cfg['image_dir'],d_part,cls)
        makeDirIfNotExist(directory)
# Out:
# **makeDirIfNotExist** : Directory /home/cecuser/5050/aicoc-ai-immersion/FastAI/class_images/train/people_wearing_masks already exists ..
# **makeDirIfNotExist** : Directory /home/cecuser/5050/aicoc-ai-immersion/FastAI/class_images/train/people_posing_street already exists ..
# **makeDirIfNotExist** : Directory /home/cecuser/5050/aicoc-ai-immersion/FastAI/class_images/train/people_skateboarding already exists ..
# **makeDirIfNotExist** : Directory /home/cecuser/5050/aicoc-ai-immersion/FastAI/class_images/train/people_on_bikes already exists ..

# %% [markdown]
# ## Install Googliser here.
# This handy utility will download our images from google images.  We will clone the repo from git.

# %%
# install googliser
def install_googliser():
    googliser_directory = cfg['base_dir']+"/googliser"
    if not os.path.exists(googliser_directory):  
        nprint("Installing Googliser here : {} ".format(googliser_directory))
        os.chdir(cfg['base_dir'])
        # !git clone https://github.com/teracow/googliser
    else :
        nprint("Googliser already installed here : {} ".format(googliser_directory))

    googliser = cfg['base_dir']+"/googliser/googliser.sh"

    return googliser 
googliser = install_googliser()
# !ls {googliser}
# Out:
# **install_googliser** : Googliser already installed here : /home/cecuser/5050/aicoc-ai-immersion/FastAI/googliser
# /home/cecuser/5050/aicoc-ai-immersion/FastAI/googliser/googliser.sh

# %% [markdown]
# ## How many images should we grab ?
#
# Luckily not too many.. it always depends on the project, but we are going to use a pre-training deep learning network when we perform training.  Since that network was already trained on over 1 million images, we don't need to supply too many for our task.  This is why transfer learning is so powerful!

# %%
cfg['num_images']
# Out:
# {'train': 200, 'valid': 20, 'test': 20}

# %%
# The code below will download files to train folder only to avoid duplicate downloads.  
# We then move a few files over.  This can be done manually or programatically.  For our example
# we will let FastAI do the work for us!

def download_images(cfg):
    utility_dir = cfg['base_dir']
    for d_p in cfg["d_partitions"] : # train only for now ..
        for cls in cfg["classes"] :
            current_dir =class_folder_name(cfg['image_dir'],d_p,cls)
            #os.chdir(current_dir)
            os.chdir(utility_dir)
            command = googliser + \
                      " --o {}".format(current_dir) +\
                      " --phrase \"{}\"".format(cls) + \
                      " --parallel 50 --upper-size 500000 --lower-size 2000 " + \
                      " -n {}".format(cfg['num_images'][d_p]) + \
                      " --format jpg --timeout 15 --safesearch-off "
            nprint(command)
            # !{command}
    nprint("Downloads complete!")
download_images(cfg)

# This will take ~5 mins depending on how many classes / images we are grabbing...
# Out:
# **download_images** : /home/cecuser/5050/aicoc-ai-immersion/FastAI/googliser/googliser.sh --o /home/cecuser/5050/aicoc-ai-immersion/FastAI/class_images/train/people_wearing_masks --phrase "people wearing masks" --parallel 50 --upper-size 500000 --lower-size 2000  -n 200 --format jpg --timeout 15 --safesearch-off
#  googliser.sh v:200212 PID:1366
#
#    Google: 0/10 web pages OK, 1/10 are in progres0/10 web pages OK, 2/10 are in progres0/10 web pages OK, 3/10 are in progres0/10 web pages OK, 4/10 are in progres0/10 web pages OK, 5/10 are in progres0/10 web pages OK, 6/10 are in progres0/10 web pages OK, 7/10 are in progres0/10 web pages OK, 8/10 are in progres0/10 web pages OK, 9/10 are in progres0/10 web pages OK, 10/10 are in progress10 web pages OK
#     links: 77
#  download: 0/77 images OK0/77 images OK, 1/50 are in progress0/77 images OK, 2/50 are in progress0/77 images OK, 3/50 are in progress0/77 images OK, 4/50 are in progress0/77 images OK, 5/50 are in progress0/77 images OK, 6/50 are in progress0/77 images OK, 7/50 are in progress0/77 images OK, 8/50 are in progress0/77 images OK, 9/50 are in progress0/77 images OK, 10/50 are in progres0/77 images OK, 11/50 are in progres0/77 images OK, 11/50 are in progress and 1 have faile0/77 images OK, 12/50 are in progress and 1 have faile0/77 images OK, 13/50 are in progress and 1 have faile0/77 images OK, 14/50 are in progress and 1 have faile0/77 images OK, 15/50 are in progress and 1 have faile0/77 images OK, 16/50 are in progress and 1 have faile0/77 images OK, 17/50 are in progress and 1 have faile0/77 images OK, 18/50 are in progress and 1 have faile0/77 images OK, 19/50 are in progress and 2 have faile0/77 images OK, 18/50 are in progress and 3 have faile0/77 images OK, 19/50 are in progress and 3 have faile0/77 images OK, 20/50 are in progress and 3 have faile0/77 images OK, 21/50 are in progress and 3 have faile0/77 images OK, 20/50 are in progress and 5 have faile0/77 images OK, 21/50 are in progress and 5 have faile0/77 images OK, 22/50 are in progress and 5 have faile0/77 images OK, 23/50 are in progress and 5 have faile0/77 images OK, 24/50 are in progress and 5 have faile0/77 images OK, 25/50 are in progress and 6 have faile0/77 images OK, 26/50 are in progress and 6 have faile0/77 images OK, 27/50 are in progress and 6 have faile0/77 images OK, 28/50 are in progress and 6 have faile2/77 images OK, 26/50 are in progress and 7 have faile2/77 images OK, 27/50 are in progress and 7 have faile2/77 images OK, 27/50 are in progress and 8 have faile2/77 images OK, 27/50 are in progress and 9 have faile2/77 images OK, 27/50 are in progress and 10 have failed2/77 images OK, 28/50 are in progress and 10 have failed5/77 images OK, 27/50 are in progress and 10 have failed5/77 images OK, 28/50 are in progress and 10 have failed5/77 images OK, 29/50 are in progress and 11 have failed5/77 images OK, 28/50 are in progress and 13 have failed5/77 images OK, 29/50 are in progress and 13 have failed5/77 images OK, 30/50 are in progress and 13 have failed5/77 images OK, 31/50 are in progress and 13 have failed5/77 images OK, 32/50 are in progress and 13 have failed5/77 images OK, 32/50 are in progress and 14 have failed5/77 images OK, 33/50 are in progress and 14 have failed6/77 images OK, 33/50 are in progress and 14 have failed7/77 images OK, 33/50 are in progress and 14 have failed7/77 images OK, 34/50 are in progress and 14 have failed9/77 images OK, 32/50 are in progress and 15 have failed9/77 images OK, 33/50 are in progress and 15 have failed9/77 images OK, 34/50 are in progress and 15 have failed9/77 images OK, 34/50 are in progress and 16 have failed9/77 images OK, 34/50 are in progress and 17 have failed9/77 images OK, 34/50 are in progress and 18 have failed9/77 images OK, 35/50 are in progress and 18 have failed9/77 images OK, 36/50 are in progress and 18 have failed11/77 images OK, 35/50 are in progress and 18 have faile12/77 images OK, 35/50 are in progress and 18 have faile12/77 images OK, 36/50 are in progress and 19 have faile13/77 images OK, 35/50 are in progress and 19 have faile15/77 images OK, 34/50 are in progress and 19 have faile15/77 images OK, 34/50 are in progress and 20 have faile15/77 images OK, 35/50 are in progress and 21 have faile15/77 images OK, 34/50 are in progress and 22 have faile15/77 images OK, 35/50 are in progress and 22 have faile15/77 images OK, 36/50 are in progress and 22 have faile16/77 images OK, 37/50 are in progress and 22 have faile16/77 images OK, 37/50 are in progress and 23 have faile17/77 images OK, 36/50 are in progress and 23 have faile17/77 images OK, 36/50 are in progress and 24 have faile18/77 images OK, 35/50 are in progress and 24 have faile19/77 images OK, 35/50 are in progress and 24 h ...
# **download_images** : /home/cecuser/5050/aicoc-ai-immersion/FastAI/googliser/googliser.sh --o /home/cecuser/5050/aicoc-ai-immersion/FastAI/class_images/train/people_posing_street --phrase "people posing street" --parallel 50 --upper-size 500000 --lower-size 2000  -n 200 --format jpg --timeout 15 --safesearch-off
#  googliser.sh v:200212 PID:24164
#
#    Google: 0/10 web pages OK, 1/10 are in progres0/10 web pages OK, 2/10 are in progres0/10 web pages OK, 3/10 are in progres0/10 web pages OK, 4/10 are in progres0/10 web pages OK, 5/10 are in progres0/10 web pages OK, 6/10 are in progres0/10 web pages OK, 7/10 are in progres0/10 web pages OK, 8/10 are in progres0/10 web pages OK, 9/10 are in progres0/10 web pages OK, 10/10 are in progress10 web pages OK
#     links: 96
#  download: 0/96 images OK0/96 images OK, 1/50 are in progress0/96 images OK, 2/50 are in progress0/96 images OK, 3/50 are in progress0/96 images OK, 4/50 are in progress0/96 images OK, 5/50 are in progress0/96 images OK, 6/50 are in progress0/96 images OK, 7/50 are in progress0/96 images OK, 8/50 are in progress0/96 images OK, 9/50 are in progress0/96 images OK, 10/50 are in progres0/96 images OK, 11/50 are in progres0/96 images OK, 12/50 are in progres0/96 images OK, 13/50 are in progres0/96 images OK, 14/50 are in progres0/96 images OK, 15/50 are in progres0/96 images OK, 16/50 are in progres0/96 images OK, 17/50 are in progres0/96 images OK, 18/50 are in progres0/96 images OK, 19/50 are in progres0/96 images OK, 20/50 are in progres0/96 images OK, 21/50 are in progres1/96 images OK, 21/50 are in progres1/96 images OK, 22/50 are in progres1/96 images OK, 23/50 are in progres2/96 images OK, 23/50 are in progres2/96 images OK, 24/50 are in progres3/96 images OK, 24/50 are in progres3/96 images OK, 25/50 are in progres5/96 images OK, 24/50 are in progres7/96 images OK, 22/50 are in progress and 1 have faile8/96 images OK, 22/50 are in progress and 1 have faile8/96 images OK, 23/50 are in progress and 1 have faile9/96 images OK, 22/50 are in progress and 2 have faile11/96 images OK, 23/50 are in progress and 2 have failed11/96 images OK, 22/50 are in progress and 2 have failed12/96 images OK, 22/50 are in progress and 2 have failed12/96 images OK, 23/50 are in progress and 2 have failed12/96 images OK, 24/50 are in progress and 2 have failed12/96 images OK, 25/50 are in progress and 2 have failed14/96 images OK, 24/50 are in progress and 2 have failed15/96 images OK, 24/50 are in progress and 2 have failed15/96 images OK, 25/50 are in progress and 2 have failed15/96 images OK, 26/50 are in progress and 2 have failed15/96 images OK, 27/50 are in progress and 2 have failed16/96 images OK, 26/50 are in progress and 3 have failed16/96 images OK, 27/50 are in progress and 3 have failed16/96 images OK, 27/50 are in progress and 4 have failed18/96 images OK, 27/50 are in progress and 4 have failed19/96 images OK, 25/50 are in progress and 5 have failed22/96 images OK, 24/50 are in progress and 5 have failed22/96 images OK, 23/50 are in progress and 6 have failed22/96 images OK, 24/50 are in progress and 6 have failed23/96 images OK, 24/50 are in progress and 6 have failed23/96 images OK, 25/50 are in progress and 6 have failed23/96 images OK, 26/50 are in progress and 6 have failed23/96 images OK, 27/50 are in progress and 6 have failed24/96 images OK, 27/50 are in progress and 6 have failed24/96 images OK, 28/50 are in progress and 6 have failed24/96 images OK, 29/50 are in progress and 6 have failed25/96 images OK, 29/50 are in progress and 6 have failed25/96 images OK, 29/50 are in progress and 7 have failed25/96 images OK, 30/50 are in progress and 7 have failed25/96 images OK, 31/50 are in progress and 8 have failed26/96 images OK, 30/50 are in progress and 8 have failed26/96 images OK, 31/50 are in progress and 8 have failed28/96 images OK, 29/50 are in progress and 9 have failed28/96 images OK, 30/50 are in progress and 9 have failed29/96 images OK, 30/50 are in progress and 9 have failed32/96 images OK, 27/50 are in progress and 10 have faile34/96 images OK, 27/50 are in progress and 10 have faile34/96 images OK, 28/50 are in progress and 10 have faile34/96 images OK, 29/50 are in progress and 10 have faile35/96 images OK, 29/50 are in progress and 10 have faile35/96 images OK, 30/50 are in progress and 10 have faile35/96 images OK, 31/50 are in progress and 10 have faile37/96 images OK, 30/50 are in progress and 10 have faile39/96 images OK, 29/50 are in progress and 10 have faile40/96 images OK, 29/50 are in progress and 10 have faile40/96 images OK, 30/50 are in progress and 10 have faile41/96 images OK, 30/50 are in progress and 10 have faile41/96 images OK, 31/50 are in progress and 10 have faile41/96 images OK, 32/50 are  ...
# **download_images** : /home/cecuser/5050/aicoc-ai-immersion/FastAI/googliser/googliser.sh --o /home/cecuser/5050/aicoc-ai-immersion/FastAI/class_images/train/people_skateboarding --phrase "people skateboarding" --parallel 50 --upper-size 500000 --lower-size 2000  -n 200 --format jpg --timeout 15 --safesearch-off
#  googliser.sh v:200212 PID:2594
#
#    Google: 0/10 web pages OK, 1/10 are in progres0/10 web pages OK, 2/10 are in progres0/10 web pages OK, 3/10 are in progres0/10 web pages OK, 4/10 are in progres0/10 web pages OK, 5/10 are in progres0/10 web pages OK, 6/10 are in progres0/10 web pages OK, 7/10 are in progres0/10 web pages OK, 8/10 are in progres0/10 web pages OK, 9/10 are in progres0/10 web pages OK, 10/10 are in progress10 web pages OK
#     links: 89
#  download: 0/89 images OK0/89 images OK, 1/50 are in progress0/89 images OK, 2/50 are in progress0/89 images OK, 3/50 are in progress0/89 images OK, 4/50 are in progress0/89 images OK, 5/50 are in progress0/89 images OK, 6/50 are in progress0/89 images OK, 7/50 are in progress0/89 images OK, 8/50 are in progress0/89 images OK, 9/50 are in progress0/89 images OK, 10/50 are in progres0/89 images OK, 11/50 are in progres0/89 images OK, 12/50 are in progres0/89 images OK, 13/50 are in progres0/89 images OK, 14/50 are in progres0/89 images OK, 15/50 are in progres0/89 images OK, 16/50 are in progres0/89 images OK, 17/50 are in progres0/89 images OK, 18/50 are in progres0/89 images OK, 19/50 are in progress and 1 have faile0/89 images OK, 20/50 are in progress and 1 have faile0/89 images OK, 21/50 are in progress and 1 have faile0/89 images OK, 22/50 are in progress and 1 have faile0/89 images OK, 23/50 are in progress and 2 have faile0/89 images OK, 24/50 are in progress and 2 have faile1/89 images OK, 25/50 are in progress and 2 have faile2/89 images OK, 24/50 are in progress and 2 have faile2/89 images OK, 25/50 are in progress and 2 have faile2/89 images OK, 26/50 are in progress and 2 have faile3/89 images OK, 27/50 are in progress and 3 have faile3/89 images OK, 26/50 are in progress and 3 have faile3/89 images OK, 27/50 are in progress and 3 have faile3/89 images OK, 28/50 are in progress and 3 have faile4/89 images OK, 28/50 are in progress and 5 have faile5/89 images OK, 25/50 are in progress and 6 have faile6/89 images OK, 26/50 are in progress and 6 have faile7/89 images OK, 25/50 are in progress and 6 have faile7/89 images OK, 26/50 are in progress and 6 have faile7/89 images OK, 27/50 are in progress and 6 have faile8/89 images OK, 27/50 are in progress and 6 have faile9/89 images OK, 28/50 are in progress and 6 have faile11/89 images OK, 26/50 are in progress and 6 have failed12/89 images OK, 25/50 are in progress and 7 have failed13/89 images OK, 25/50 are in progress and 7 have failed13/89 images OK, 26/50 are in progress and 7 have failed13/89 images OK, 27/50 are in progress and 7 have failed13/89 images OK, 28/50 are in progress and 8 have failed13/89 images OK, 27/50 are in progress and 9 have failed13/89 images OK, 28/50 are in progress and 9 have failed16/89 images OK, 27/50 are in progress and 9 have failed17/89 images OK, 26/50 are in progress and 10 have faile18/89 images OK, 25/50 are in progress and 10 have faile18/89 images OK, 26/50 are in progress and 10 have faile18/89 images OK, 26/50 are in progress and 11 have faile19/89 images OK, 26/50 are in progress and 12 have faile20/89 images OK, 25/50 are in progress and 12 have faile21/89 images OK, 25/50 are in progress and 12 have faile21/89 images OK, 26/50 are in progress and 12 have faile22/89 images OK, 25/50 are in progress and 13 have faile23/89 images OK, 25/50 are in progress and 13 have faile23/89 images OK, 25/50 are in progress and 14 have faile23/89 images OK, 26/50 are in progress and 14 have faile23/89 images OK, 27/50 are in progress and 14 have faile23/89 images OK, 28/50 are in progress and 14 have faile23/89 images OK, 28/50 are in progress and 15 have faile23/89 images OK, 29/50 are in progress and 15 have faile23/89 images OK, 30/50 are in progress and 15 have faile25/89 images OK, 29/50 are in progress and 16 have faile28/89 images OK, 27/50 are in progress and 16 have faile29/89 images OK, 26/50 are in progress and 16 have faile32/89 images OK, 24/50 are in progress and 16 have faile32/89 images OK, 25/50 are in progress and 16 have faile34/89 images OK, 23/50 are in progress and 17 have faile34/89 images OK, 24/50 are in progress and 17 have faile34/89 images OK, 25/50 are in progress and 17 have faile34/89 images OK, 26/50 are in progress and 17 have faile34/89 images OK, 27/50 are in progress and 17 have faile35/89 images OK, 27/50 are in progress and 17 have faile35/89 images OK, 28/50 are in progress and 17 have faile35/89 image ...
# **download_images** : /home/cecuser/5050/aicoc-ai-immersion/FastAI/googliser/googliser.sh --o /home/cecuser/5050/aicoc-ai-immersion/FastAI/class_images/train/people_on_bikes --phrase "people on bikes" --parallel 50 --upper-size 500000 --lower-size 2000  -n 200 --format jpg --timeout 15 --safesearch-off
#  googliser.sh v:200212 PID:31548
#
#    Google: 0/10 web pages OK, 1/10 are in progres0/10 web pages OK, 2/10 are in progres0/10 web pages OK, 3/10 are in progres0/10 web pages OK, 4/10 are in progres0/10 web pages OK, 5/10 are in progres0/10 web pages OK, 6/10 are in progres0/10 web pages OK, 7/10 are in progres0/10 web pages OK, 8/10 are in progres0/10 web pages OK, 9/10 are in progres0/10 web pages OK, 10/10 are in progress10 web pages OK
#     links: 87
#  download: 0/87 images OK0/87 images OK, 1/50 are in progress0/87 images OK, 2/50 are in progress0/87 images OK, 3/50 are in progress0/87 images OK, 4/50 are in progress0/87 images OK, 5/50 are in progress0/87 images OK, 6/50 are in progress0/87 images OK, 6/50 are in progress and 1 have failed0/87 images OK, 7/50 are in progress and 1 have failed1/87 images OK, 7/50 are in progress and 1 have failed1/87 images OK, 8/50 are in progress and 1 have failed1/87 images OK, 9/50 are in progress and 1 have failed1/87 images OK, 10/50 are in progress and 1 have faile1/87 images OK, 11/50 are in progress and 1 have faile1/87 images OK, 12/50 are in progress and 1 have faile1/87 images OK, 13/50 are in progress and 1 have faile1/87 images OK, 14/50 are in progress and 1 have faile1/87 images OK, 15/50 are in progress and 1 have faile1/87 images OK, 16/50 are in progress and 1 have faile1/87 images OK, 17/50 are in progress and 1 have faile1/87 images OK, 18/50 are in progress and 1 have faile1/87 images OK, 19/50 are in progress and 1 have faile1/87 images OK, 20/50 are in progress and 1 have faile1/87 images OK, 21/50 are in progress and 1 have faile4/87 images OK, 19/50 are in progress and 1 have faile4/87 images OK, 20/50 are in progress and 1 have faile4/87 images OK, 21/50 are in progress and 1 have faile6/87 images OK, 21/50 are in progress and 1 have faile6/87 images OK, 22/50 are in progress and 1 have faile6/87 images OK, 22/50 are in progress and 2 have faile6/87 images OK, 23/50 are in progress and 2 have faile6/87 images OK, 24/50 are in progress and 2 have faile6/87 images OK, 25/50 are in progress and 2 have faile6/87 images OK, 25/50 are in progress and 3 have faile6/87 images OK, 26/50 are in progress and 3 have faile7/87 images OK, 27/50 are in progress and 3 have faile8/87 images OK, 27/50 are in progress and 3 have faile8/87 images OK, 28/50 are in progress and 3 have faile8/87 images OK, 29/50 are in progress and 3 have faile9/87 images OK, 28/50 are in progress and 4 have faile9/87 images OK, 29/50 are in progress and 4 have faile9/87 images OK, 30/50 are in progress and 4 have faile10/87 images OK, 30/50 are in progress and 4 have failed10/87 images OK, 31/50 are in progress and 4 have failed10/87 images OK, 32/50 are in progress and 4 have failed12/87 images OK, 32/50 are in progress and 4 have failed12/87 images OK, 31/50 are in progress and 5 have failed13/87 images OK, 30/50 are in progress and 6 have failed14/87 images OK, 29/50 are in progress and 8 have failed14/87 images OK, 30/50 are in progress and 8 have failed15/87 images OK, 30/50 are in progress and 8 have failed15/87 images OK, 31/50 are in progress and 8 have failed16/87 images OK, 30/50 are in progress and 9 have failed16/87 images OK, 31/50 are in progress and 9 have failed16/87 images OK, 32/50 are in progress and 9 have failed17/87 images OK, 31/50 are in progress and 10 have faile17/87 images OK, 32/50 are in progress and 10 have faile17/87 images OK, 32/50 are in progress and 12 have faile18/87 images OK, 32/50 are in progress and 12 have faile19/87 images OK, 31/50 are in progress and 12 have faile19/87 images OK, 31/50 are in progress and 13 have faile19/87 images OK, 32/50 are in progress and 13 have faile21/87 images OK, 31/50 are in progress and 13 have faile21/87 images OK, 32/50 are in progress and 13 have faile21/87 images OK, 33/50 are in progress and 14 have faile22/87 images OK, 31/50 are in progress and 15 have faile23/87 images OK, 31/50 are in progress and 15 have faile24/87 images OK, 31/50 are in progress and 15 have faile24/87 images OK, 32/50 are in progress and 15 have faile24/87 images OK, 33/50 are in progress and 15 have faile26/87 images OK, 31/50 are in progress and 16 have faile29/87 images OK, 29/50 are in progress and 16 have faile29/87 images OK, 30/50 are in progress and 16 have faile30/87 images OK, 30/50 are in progress and 16 have faile30/87 images OK, 31/50 are in progress and 16 have faile30/87 images OK, 32/5 ...
# **download_images** : Downloads complete!

# %% [markdown]
# ## Clean up downloaded images that are not proper jpeg format ..

# %%
# clean with jpeginfo! 
def clean_up_bad_images(cfg):
    os.chdir(cfg['image_dir'])
    nprint("Search for Error files in {}......".format(cfg['image_dir']))
    # handle both jpg //jpeg files that are malformed
    for ext in ["jpg","jpeg"] :
        command = "find . -name \"*.{}\"".format(ext) + \
          " | xargs -i {}".format(cfg["jpeginfo"]) + \
          " -c {} | grep ERROR"
        nprint("Running command : {}".format(command))
        # !{command}
        nprint("Removing any error files listed above")
        command = command + ' | cut -d " " -f1 | xargs -i rm {} '
        nprint("Running command : {}".format(command))
        # !{command}
        nprint("Done")
    # get rid of png /webp
    for ext in ["png", "webp"]:
        command = "find . -name \"*.{}\"".format(ext) + \
            " | xargs -i rm -f {}"
        nprint("Running command : {}".format(command))
        # !{command}
        
clean_up_bad_images(cfg)

# find . -name "*.jpg," | xargs -i ./jpeginfo -c {}
# find . -name "*.jpg" | xargs -i ./jpeginfo -c {} | grep ERROR | cut -d " " -f1 | xargs -i rm {}
# Out:
# **clean_up_bad_images** : Search for Error files in /home/cecuser/5050/aicoc-ai-immersion/FastAI/class_images......
# **clean_up_bad_images** : Running command : find . -name "*.jpg" | xargs -i /home/cecuser/5050/aicoc-ai-immersion/FastAI/jpeginfo -c {} | grep ERROR
# ./train/people_wearing_masks/image(0069).jpg  Not a JPEG file: starts with 0x52 0x49  [ERROR]
# ./train/people_posing_street/image(0020).jpg  Not a JPEG file: starts with 0x52 0x49  [ERROR]
# ./train/people_posing_street/image(0069).jpg  Not a JPEG file: starts with 0x52 0x49  [ERROR]
# ./train/people_posing_street/image(0089).jpg  Not a JPEG file: starts with 0x52 0x49  [ERROR]
# ./train/people_skateboarding/image(0041).jpg  Not a JPEG file: starts with 0x89 0x50  [ERROR]
# ./train/people_on_bikes/image(0075).jpg  Not a JPEG file: starts with 0x52 0x49  [ERROR]
# ./train/people_on_bikes/image(0054).jpg  Not a JPEG file: starts with 0x52 0x49  [ERROR]
# **clean_up_bad_images** : Removing any error files listed above
# **clean_up_bad_images** : Running command : find . -name "*.jpg" | xargs -i /home/cecuser/5050/aicoc-ai-immersion/FastAI/jpeginfo -c {} | grep ERROR | cut -d " " -f1 | xargs -i rm {}
# **clean_up_bad_images** : Done
# **clean_up_bad_images** : Running command : find . -name "*.jpeg" | xargs -i /home/cecuser/5050/aicoc-ai-immersion/FastAI/jpeginfo -c {} | grep ERROR
# ./train/people_skateboarding/image(0005).jpeg  Not a JPEG file: starts with 0x52 0x49  [ERROR]
# **clean_up_bad_images** : Removing any error files listed above
# **clean_up_bad_images** : Running command : find . -name "*.jpeg" | xargs -i /home/cecuser/5050/aicoc-ai-immersion/FastAI/jpeginfo -c {} | grep ERROR | cut -d " " -f1 | xargs -i rm {}
# **clean_up_bad_images** : Done
# **clean_up_bad_images** : Running command : find . -name "*.png" | xargs -i rm -f {}
# **clean_up_bad_images** : Running command : find . -name "*.webp" | xargs -i rm -f {}

# %%
#path = untar_data(URLs.PETS); path
path = Path(cfg['image_dir'])

# %%
path.ls()
#cfg['image_dir']
# Out:
# [PosixPath('/home/cecuser/5050/aicoc-ai-immersion/FastAI/class_images/train'),
#  PosixPath('/home/cecuser/5050/aicoc-ai-immersion/FastAI/class_images/models')]

# %% [markdown]
# The first thing we do when we approach a problem is to take a look at the data. We _always_ need to understand very well what the problem is and what the data looks like before we can figure out how to solve it. Taking a look at the data means understanding how the data directories are structured, what the labels are and what some sample images look like.
#
# The main difference between the handling of image classification datasets is the way labels are stored. In this particular dataset, labels are stored in the filenames themselves. We will need to extract them to be able to classify the images into the correct categories. Fortunately, the fastai library has a handy function made exactly for this, `ImageDataBunch.from_name_re` gets the labels from the filenames using a [regular expression](https://docs.python.org/3.6/library/re.html).

# %% [markdown]
# ## Create Data Bunch
# Fastai has a number of methods to create a data bunch. Lets look at some of the documentation using **doc** function

# %%
#doc(ImageDataBunch)
doc(ImageDataBunch.from_folder)

# %%
# https://docs.fast.ai/vision.data.html#ImageDataBunch.from_folder
## Important, batch size should be set lower than the number of images you have
data = ImageDataBunch.from_folder(path=cfg['image_dir'],
                train="train",valid_pct=0.20,no_check=True,
                size=224,num_workers=4,bs=cfg["bs"]).normalize(imagenet_stats)

# %%
data
# Out:
# ImageDataBunch;
#
# Train: LabelList (209 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# people_wearing_masks,people_wearing_masks,people_wearing_masks,people_wearing_masks,people_wearing_masks
# Path: /home/cecuser/5050/aicoc-ai-immersion/FastAI/class_images;
#
# Valid: LabelList (52 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# people_posing_street,people_skateboarding,people_posing_street,people_skateboarding,people_posing_street
# Path: /home/cecuser/5050/aicoc-ai-immersion/FastAI/class_images;
#
# Test: None

# %%
data.show_batch(rows=4, figsize=(9,9))
#data.show_batch(figsize=(4,4))

# %%
data.label_list
# Out:
# LabelLists;
#
# Train: LabelList (209 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# people_wearing_masks,people_wearing_masks,people_wearing_masks,people_wearing_masks,people_wearing_masks
# Path: /home/cecuser/5050/aicoc-ai-immersion/FastAI/class_images;
#
# Valid: LabelList (52 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# people_posing_street,people_skateboarding,people_posing_street,people_skateboarding,people_posing_street
# Path: /home/cecuser/5050/aicoc-ai-immersion/FastAI/class_images;
#
# Test: None

# %%
print(data.classes)
len(data.classes),data.c
# Out:
# ['people_on_bikes', 'people_posing_street', 'people_skateboarding', 'people_wearing_masks']
# (4, 4)

# %% [markdown]
# ## Training: resnet34

# %% [markdown]
# Now we will start training our model. We will use a [convolutional neural network](http://cs231n.github.io/convolutional-networks/) backbone and a fully connected head with a single hidden layer as a classifier. Don't know what these things mean? Not to worry, we will dive deeper in the coming lessons. For the moment you need to know that we are building a model which will take images as input and will output the predicted probability for each of the categories (in this case, it will have 37 outputs).

# %%
#create learner
learn = cnn_learner(data, models.resnet34, metrics=error_rate)

# %%
# save pretrained model ..
learn.model
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (4): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (5): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (1): Sequential(
#     (0): AdaptiveConcatPool2d(
#       (ap): AdaptiveAvgPool2d(output_size=1)
#       (mp): AdaptiveMaxPool2d(output_size=1)
#     )
#     (1): Flatten()
#     (2): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=1024, out_features=512, bias=True)
#     (5): ReLU(inplace=True)
#     (6): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.5, inplace=False)
#     (8): Linear(in_features=512, out_features=4, bias=True)
#   )
# )

# %%
# dont worry about the #na#, as long as we get a plot in the next section, great!
learn.lr_find() # num_it=36, stop_div=False
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='6' class='' max='8' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       75.00% [6/8 00:50<00:16]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.619608</td>
#       <td>#na#</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.635780</td>
#       <td>#na#</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.578467</td>
#       <td>#na#</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.268834</td>
#       <td>#na#</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.763350</td>
#       <td>#na#</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.869218</td>
#       <td>#na#</td>
#       <td>00:08</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='10' class='' max='13' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       76.92% [10/13 00:07<00:02 5.7822]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
# Run 5 epochs (can do more if still getting better train / val)
# FILL IN THE RANGE BASE ON YOUR LRFIND RESULT
learn.fit_one_cycle(5, max_lr=slice(5e-5,1e-2))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.311313</td>
#       <td>0.302648</td>
#       <td>0.096154</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.871004</td>
#       <td>0.432219</td>
#       <td>0.115385</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.669012</td>
#       <td>0.384389</td>
#       <td>0.096154</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.483604</td>
#       <td>0.298260</td>
#       <td>0.076923</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.354789</td>
#       <td>0.273837</td>
#       <td>0.076923</td>
#       <td>00:10</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Results

# %% [markdown]
# Let's see what results we have got.
#
# We will first see which were the categories that the model most confused with one another. We will try to see if what the model predicted was reasonable or not. In this case the mistakes look reasonable (none of the mistakes seems obviously naive). This is an indicator that our classifier is working correctly.
#
# Furthermore, when we plot the confusion matrix, if we can see that the distribution is heavily skewed: the model makes the same mistakes over and over again but it rarely confuses other categories. This suggests that it just finds it difficult to distinguish some specific categories between each other; this is normal behaviour.

# %%
interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
doc(interp.plot_top_losses)

# %%
interp.plot_top_losses(9, figsize=(19,11),heatmap=True)

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)
interp.confusion_matrix()
# Out:
# array([[ 9,  0,  0,  0],
#        [ 0, 19,  2,  1],
#        [ 0,  0, 13,  0],
#        [ 0,  1,  0,  7]])

# %%
interp.most_confused(min_val=2)
# Out:
# [('people_posing_street', 'people_skateboarding', 2)]

# %% [markdown]
# ## Unfreezing, fine-tuning, and learning rates

# %% [markdown]
# Since our model is working as we expect it to, we will *unfreeze* our model and train some more.

# %%
learn.save('stage-1')
learn.unfreeze()

# %%
learn.fit_one_cycle(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.116359</td>
#       <td>1.186250</td>
#       <td>0.230769</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.329620</td>
#       <td>2.061262</td>
#       <td>0.288462</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.640099</td>
#       <td>1.198242</td>
#       <td>0.211538</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.587477</td>
#       <td>0.517251</td>
#       <td>0.153846</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.459649</td>
#       <td>0.443841</td>
#       <td>0.153846</td>
#       <td>00:10</td>
#     </tr>
#   </tbody>
# </table>

# %%
#learn.save('stage-2')
#learn.load('stage-1');
#learn.unfreeze(-2)
#learn.fit_one_cycle(2, max_lr=slice(1e-6,1e-3))

# %%
interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()
len(data.valid_ds)==len(losses)==len(idxs)
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %% [markdown]
# That's a pretty accurate model!

# %% [markdown]
# ## Training: resnet50

# %% [markdown]
# Now we will train in the same way as before but with one caveat: instead of using resnet34 as our backbone we will use resnet50 (resnet34 is a 34 layer residual network while resnet50 has 50 layers. It will be explained later in the course and you can learn the details in the [resnet paper](https://arxiv.org/pdf/1512.03385.pdf)).
#
# Basically, resnet50 usually performs better because it is a deeper network with more parameters. Let's see if we can achieve a higher performance here. To help it along, let's us use larger images too, since that way the network can see more detail. We reduce the batch size a bit since otherwise this larger network will require more GPU memory.

# %% [markdown]
# ## Optional Assignment
# Can you redo the training above with a different pre-trained model ???  See this page for some ideas
#
# https://docs.fast.ai/vision.models.html
#
# * Hint : in a a code cell type  models.\<<tab\>>

# %%
doc(cnn_learner)

# %%
#learn = cnn_learner(data, FILL_IN_HERE!!, metrics=error_rate)
learn = cnn_learner(data, models.vgg11_bn, metrics=error_rate)
# model.alexnet

# %%
learn.lr_find()
learn.recorder.plot()

# %%
learn.fit_one_cycle(2) # 2 epochs ...

# %%
learn.save('stage-1-custom')

# %% [markdown]
# ## Lets continue to tune ...

# %%
learn.unfreeze()
learn.fit_one_cycle(3, max_lr=slice(1e-6,1e-4))

# %% [markdown]
# If it doesn't get better results, you can always go back to your previous model.

# %%
learn.load('stage-1-50');

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %%
interp.most_confused(min_val=2)

# %% [markdown]
# # Advanced Example :  Loading Data from PAIV / IVI
#
# So you want to train on some data that maybe you labelled in another tool ?  No problem.  Here we show how you could read in data exported from PAIV and classifying in this tool ...
#
# For our IBM Visual Insights Example, we can just run a nice utility to reformat the output.  For convenience, we added a **Bananas Dataset** to our repo to play with ..

# %%
os.chdir(cfg["base_dir"])
# !ls *.zip
# Out:
# Bananas.zip

# %% [markdown]
# ## Unzip our bananas data and convert to images in sub-directories
#
# When you export data from IVI, you get a single zip file.  When you unzip this file, you get a singular directory with a metadata file called prop.json.  We have a utility that will read that prop.json and create a new directory with sorted images... lets see how this works

# %%
# unzip the Bananas.zip to /tmp/bananas_ivi directory
# !sudo yum install -y unzip
# !unzip -o -d /tmp Bananas.zip
# Out:
# Loaded plugins: nvidia, product-id, search-disabled-repos, subscription-manager
# This system is not registered with an entitlement server. You can use subscription-manager to register.
# Package unzip-6.0-19.el7.ppc64le already installed and latest version
# Nothing to do
# Archive:  Bananas.zip
#   inflating: /tmp/Bananas/prop.json
#   inflating: /tmp/Bananas/ace685e2-9dd4-45ef-803c-30d8da10b0f2.jpg
#   inflating: /tmp/Bananas/50a24336-4d89-490b-af40-0be49ddeceaf.jpg
#   inflating: /tmp/Bananas/dd504896-cefd-4481-b59e-57dd76e428b7.jpg
#   inflating: /tmp/Bananas/cc8ae743-1e1a-4df1-84dd-fd731d36f1d7.jpg
#   inflating: /tmp/Bananas/725d2986-4297-4193-89ac-03e7851ac5c0.jpg
#   inflating: /tmp/Bananas/a0c0636e-4943-497b-86b6-84a59724d42a.jpg
#   inflating: /tmp/Bananas/aa4f978a-d72a-4162-bd41-59c2461ed8a4.jpg
#   inflating: /tmp/Bananas/ca50ad52-05b2-4184-ac35-439c22262579.jpg
#   inflating: /tmp/Bananas/802b5337-90e2-4521-9465-d7a337ce8903.jpg
#   inflating: /tmp/Bananas/e1a91059-d0ac-4ca0-9d52-3783adc8eb64.jpg
#   inflating: /tmp/Bananas/e4901fbd-2505-46b6-96ac-6889cff2d19d.jpg
#   inflating: /tmp/Bananas/05df2f49-b768-4041-9cdc-cb6f018c4885.jpg
#   inflating: /tmp/Bananas/8a8989b5-3f61-46d1-943a-4ed85588b1e6.jpg
#   inflating: /tmp/Bananas/a300f601-6962-4629-87e3-9d278799eef6.jpg
#   inflating: /tmp/Bananas/38e7fc0b-db8a-4a4f-877d-ef9e81176200.jpg
#   inflating: /tmp/Bananas/e914c4de-0ad7-4933-915f-66b954071214.jpg
#   inflating: /tmp/Bananas/2cb0e07b-dcd9-4465-8201-a719fc63a671.jpg
#   inflating: /tmp/Bananas/f19f3381-b350-47f3-b1b4-5d79b52a3afd.jpg
#   inflating: /tmp/Bananas/aa570949-1b26-4fbf-b5ca-a418d02cddfa.jpg
#   inflating: /tmp/Bananas/6ae348a1-6fc7-49a8-a5ea-37488d0ec95b.jpg
#   inflating: /tmp/Bananas/bcd443ee-f1a7-4623-9dd6-f49ee08f1898.jpg
#   inflating: /tmp/Bananas/deca90e3-d3a7-4c4f-93e9-02a96db05d48.jpg
#   inflating: /tmp/Bananas/4f093042-0e23-4e8f-8d08-4197a3ee7fd2.jpg
#   inflating: /tmp/Bananas/11b85ae9-3559-4242-85bd-a240d9894bff.jpg
#   inflating: /tmp/Bananas/f61404e1-e4e3-4b84-9e17-4d02c68c9f7d.jpg
#   inflating: /tmp/Bananas/734e3f95-03f9-4c9b-b602-828e12fc011f.jpg
#   inflating: /tmp/Bananas/0c46d62e-b9cb-4a80-83b0-3db2c70dda9b.jpg
#   inflating: /tmp/Bananas/6c8baf99-ad06-43f7-9be1-994aff509886.jpg
#   inflating: /tmp/Bananas/76fc0a7d-fae2-4098-980c-aef5432a105d.jpg
#   inflating: /tmp/Bananas/d4a7a7c4-848c-4457-b4ac-a6ee15a35e50.jpg
#   inflating: /tmp/Bananas/be18f944-9d1c-41a4-ba3e-ae62a929d07f.jpg
#   inflating: /tmp/Bananas/e91f3891-6659-4a6d-bfca-910ea97080ae.jpg
#   inflating: /tmp/Bananas/be45cf38-5de8-42b8-9634-f012d493daee.jpg
#   inflating: /tmp/Bananas/1927b8e0-df5d-45ac-9d94-1bced3a9b22c.jpg
#   inflating: /tmp/Bananas/fc638d87-d7d1-45b4-b629-2ac0636bafbc.jpg
#   inflating: /tmp/Bananas/5d61e6f2-1b37-4ea0-9721-655846c47d33.jpg
#   inflating: /tmp/Bananas/14511c8c-c4f2-4ac6-91f1-9c672d7f00f1.jpg
#   inflating: /tmp/Bananas/ad371efb-7dec-4564-b718-b698a98fb3d9.jpg
#   inflating: /tmp/Bananas/41e3da71-0f1a-4ee6-8d71-8d25ee229116.jpg
#   inflating: /tmp/Bananas/b4942267-b824-441e-baf3-e72cd511fed7.jpg
#   inflating: /tmp/Bananas/d98737ea-b7a1-4f20-b14d-d9a5b41169fc.jpg
#   inflating: /tmp/Bananas/d2384635-4df0-4003-92ab-c98c2ad62018.jpg
#   inflating: /tmp/Bananas/76bd5270-554f-4f6c-8226-4e8eb40a4a44.jpg
#   inflating: /tmp/Bananas/a68a0ad1-1374-4d08-b3eb-60b84c487288.jpg
#   inflating: /tmp/Bananas/9ccbb746-8185-4b36-b755-d574e9d1ec22.jpg
#   inflating: /tmp/Bananas/b23d840c-77f4-4ac9-a3ea-926e99473f13.jpg
#   inflating: /tmp/Bananas/529e1422-2355-45ab-851d-19fa2a552983.jpg
#   inflating: /tmp/Bananas/6451c527-2644-4d6b-879f-5b61b7ecd5d0.jpg
#   inflating: /tmp/Bananas/bbc38b36-1545-4a0d-a040-c8f1ad307d9b.jpg
#   inflating: /tmp/Bananas/aca8609a-020d-416d-9057-001b47aac57a.jpg
#   inflating: /tmp/Bananas/2a2a5745-9a8b-4baa-b101-77143b4b5eef.jpg
#   inflating: /tmp/Bananas/a459f1b7-8ada-4a77-8fe4-1618e0589b04.jpg
#   inflating: /tmp/Bananas/ae7ffdcd-47a5-41ea-9a69-f0e925ba68c8.jpg
#   inflating: /tmp/Bananas/6229cfde-23ac-4fbe-ba38-9115f93211ff.jpg
#   inflating: /tmp/Bananas/fc32ac31-a8f3-4b24-ab99-c4e2f6e66b23.jpg
#   inflating: /tmp/Bananas/d99d752c-d128-4c88-b796-0c5148d51728.jpg
#   inflating: /tmp/Bananas/ad89cfa0-b513-45a8-b347-59355fda6005.jpg
#   inflating: /tmp/Bananas/24e199a7-c8f4-4dbd-8b36-18fb2ba7ffe5.jpg
#   inflating: /tmp/Bananas/a7e4f754-7c88-4568-8e06-422f6272969b.jpg
#   inflating: /tmp/Bananas/701a402d-2fef-4a73-ba05-7b9458e25019.jpg
#   inflating: /tmp/Bananas/ba28ae7b-5367-412e-b854-0b34a020e954.jpg
#   inflating: /tmp/Bananas/98607fa3-4383-4f70-a124-0a2f27ab73ff.jpg
#   inflating: /tmp/Bananas/f63d1b5c-fedd-47b6-9270-cbfba49720e0.jpg
#   inflating: /tmp/Bananas/5b064e20-30bf-4db8-b41c-0033a494ac89.jpg
#   inflating: /tmp/Bananas/dcc755b3-e521-4c6b-a55c-9fede04fd4b6.jpg
#   inflating: /tmp/Bananas/5210c565-96bf-4fa1-a2cf-c6ebf165dd75.jpg
#   inflating: /tmp/Bananas/cc53a2b7-22f7-4da4-a8eb-ff2de1ecbbd0.jpg
#   inflating: /tmp/Bananas/b3227854-ff74-447a-99ce-bcafec6e08ee.jpg
#   inflating: /tmp/Bananas/0a36eefa-7748-4362-9c03-c5ebd873e648.jpg
#   inflating: /tmp/Bananas/61ea9a3e-2b52-458a-8e89-5e0c74c10b95.jpg
#   inflating: /tmp/Bananas/45cdb999-7d64-4f00-8818-9744423eef99.jpg
#   inflating: /tmp/Bananas/ac146c9e-8658-43e8-a624-a94d19896d7f.jpg
#   inflating: /tmp/Bananas/c898903d-a1a9-4637-8f8f-3c32d06cb4ad.jpg
#   inflating: /tmp/Bananas/ccd7783a-a2e4-49b4-8985-90f82fbe03c3.jpg
#   inflating: /tmp/Bananas/f2f84b0d-1ba1-449b-8e37-aabbb4f9ac0c.jpg
#   inflating: /tmp/Bananas/017948c4-8c01-45cf-a770-a3c75a3f6bb5.jpg
#   inflating: /tmp/Bananas/3f562bc9-6144-4c26-a2e4-0d93f202f0ed.jpg
#   inflating: /tmp/Bananas/f456efa9-4703-4e39-ab19-f3cea9cf2d15.jpg
#   inflating: /tmp/Bananas/ec1f6a1d-a711-4cdc-a07a-d9aa46806ed2.jpg
#   inflating: /tmp/Bananas/21867579-1a13-46c9-91c5-5b90242ed521.jpg
#   inflating: /tmp/Bananas/a0df58c7-15a8-471d-95e4-9675ce0d23af.jpg
#   inflating: /tmp/Bananas/5830daac-9f03-451b-97b9-69e426ed01ec.jpg
#   inflating: /tmp/Bananas/276179b3-c1df-4779-a694-35170372a90a.jpg
#   inflating: /tmp/Bananas/9f2791a1-f8d4-4346-bd42-6c415588285f.jpg
#   inflating: /tmp/Bananas/a366d8c0-a03b-4ed8-a768-e48f0d7d6ae2.jpg
#   inflating: /tmp/Bananas/6630eb82-253f-45a2-8940-4ee09f1135ee.jpg
#   inflating: /tmp/Bananas/6fd11ea7-70df-4964-aced-55de3fcef930.jpg
#   inflating: /tmp/Bananas/cfb830ed-2dc2-4610-963a-f2076209361a.jpg
#   inflating: /tmp/Bananas/22293fd2-71a3-41bc-af76-ee2b17567c41.jpg
#   inflating: /tmp/Bananas/b8cae979-8adc-4536-8cef-66b8b39a1e66.jpg
#   inflating: /tmp/Bananas/1c1b999d-6f13-4713-b7e5-481cffcb8a2f.jpg
#   inflating: /tmp/Bananas/2908dbe7-869e-4535-bab4-d9f7482246c5.jpg
#   inflating: /tmp/Bananas/2c00f88d-6250-43f1-85e9-ab91cb38a92b.jpg
#   inflating: /tmp/Bananas/5b428263-6938-4b51-9793-d427f77d1b25.jpg
#   inflating: /tmp/Bananas/fd7e46b1-ad39-4da0-9ffe-5e2022b4f553.jpg
#   inflating: /tmp/Bananas/f54e9c50-eea7-44f1-8567-568d73f976a5.jpg
#   inflating: /tmp/Bananas/e05418a0-2120-4e74-82ff-7316bb1aa3ef.jpg
#   inflating: /tmp/Bananas/588b766e-5484-4b19-a397-ce9264acd987.jpg
#   inflating: /tmp/Bananas/fafa901c-25b7-406e-a9c7-14d3b754b102.jpg
#   inflating: /tmp/Bananas/9d14e99f-60d4-4b5f-8d52-467ce6f021ab.jpg
#   inflating: /tmp/Bananas/74a32706-7f5d-4f44-9401-10662c4e3ced.jpg
#   inflating: /tmp/Bananas/51b2fdc6-88ba-4c6d-90ba-489b331b91ed.jpg
#   inflating: /tmp/Bananas/c7b45a97-ddf4-43d4-91c3-2a5fbcf38e96.jpg
#   inflating: /tmp/Bananas/8c7c25eb-b4d4-45e3-a091-6e87b33127d7.jpg
#   inflating: /tmp/Bananas/e5b5b747-0603-4671-8509-f0fd4fa96b94.jpg
#   inflating: /tmp/Bananas/73fa3c61-8546-44b3-8b1b-9da43377a6f7.jpg
#   inflating: /tmp/Bananas/dd79a87a-d3de-4f47-b51f-b73da0bb95be.jpg
#   inflating: /tmp/Bananas/5027b01f-3a1a-43f3-a3e4-ea264b57e3b9.jpg
#   inflating: /tmp/Bananas/c488f5af-8362-49e1-909a-2827e16074d2.jpg
#   inflating: /tmp/Bananas/d56bab27-fb17-4296-9697-466439134322.jpg
#   inflating: /tmp/Bananas/a3a69e58-2afa-4e64-ad62-16f1d209b4fb.jpg
#   inflating: /tmp/Bananas/e11979b2-d1b9-48f8-81ab-32a1710e923c.jpg
#   inflating: /tmp/Bananas/137afd8e-d7fa-4d70-b1f8-5c4cb3f4e4b3.jpg
#   inflating: /tmp/Bananas/2159c80c-ca89-44a3-a9e7-f0ecfb02c94f.jpg
#   inflating: /tmp/Bananas/be35b43d-6c54-4efe-97bb-54317f3f75f6.jpg
#   inflating: /tmp/Bananas/812bc319-69cb-4d59-8423-5fed50a3b4d4.jpg
#   inflating: /tmp/Bananas/68f4f3f5-5c05-435f-831b-9a2b14b58e77.jpg
#   inflating: /tmp/Bananas/cbf0d798-8230-4ebf-a6f4-99b7faa1a843.jpg

# %%
# Now run our handy script !
# !git clone https://github.com/dustinvanstee/powerai-vision-utils.git
# Out:
# fatal: destination path 'powerai-vision-utils' already exists and is not an empty directory.

# %%
# !conda install -y scikit-learn # dependency to run our utility ..
# !python powerai-vision-utils/reorganize_exported_dataset.py --directory_in /tmp/Bananas --directory_out /tmp/bananas_fastai/train
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.10
#   latest version: 4.8.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.
#
# directory_in /tmp/Bananas
# directory_out /tmp/bananas_fastai/train
# reformat_paiv_cls_export : classes : ['ripe', 'yellow', 'black', 'overripe', 'green']
# /tmp/bananas_fastai/train/ripe
# /tmp/bananas_fastai/train/yellow
# /tmp/bananas_fastai/train/black
# /tmp/bananas_fastai/train/overripe
# /tmp/bananas_fastai/train/green
# ofn : RP3.jpg
# ofn_root : RP3
# ofn_extention jpg
# augm : na
# newfile : RP3_na_da10b0f2.jpg
# fin : /tmp/Bananas/ace685e2-9dd4-45ef-803c-30d8da10b0f2.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP3_na_da10b0f2.jpg
# =============
# ofn : RP8.jpg
# ofn_root : RP8
# ofn_extention jpg
# augm : na
# newfile : RP8_na_9ddeceaf.jpg
# fin : /tmp/Bananas/50a24336-4d89-490b-af40-0be49ddeceaf.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP8_na_9ddeceaf.jpg
# =============
# ofn : RP9.jpg
# ofn_root : RP9
# ofn_extention jpg
# augm : na
# newfile : RP9_na_76e428b7.jpg
# fin : /tmp/Bananas/dd504896-cefd-4481-b59e-57dd76e428b7.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP9_na_76e428b7.jpg
# =============
# ofn : RP11.jpg
# ofn_root : RP11
# ofn_extention jpg
# augm : na
# newfile : RP11_na_1d36f1d7.jpg
# fin : /tmp/Bananas/cc8ae743-1e1a-4df1-84dd-fd731d36f1d7.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP11_na_1d36f1d7.jpg
# =============
# ofn : RP13.jpg
# ofn_root : RP13
# ofn_extention jpg
# augm : na
# newfile : RP13_na_851ac5c0.jpg
# fin : /tmp/Bananas/725d2986-4297-4193-89ac-03e7851ac5c0.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP13_na_851ac5c0.jpg
# =============
# ofn : RP19.jpg
# ofn_root : RP19
# ofn_extention jpg
# augm : na
# newfile : RP19_na_9724d42a.jpg
# fin : /tmp/Bananas/a0c0636e-4943-497b-86b6-84a59724d42a.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP19_na_9724d42a.jpg
# =============
# ofn : RP20.jpg
# ofn_root : RP20
# ofn_extention jpg
# augm : na
# newfile : RP20_na_461ed8a4.jpg
# fin : /tmp/Bananas/aa4f978a-d72a-4162-bd41-59c2461ed8a4.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP20_na_461ed8a4.jpg
# =============
# ofn : BY3.jpg
# ofn_root : BY3
# ofn_extention jpg
# augm : na
# newfile : BY3_na_22262579.jpg
# fin : /tmp/Bananas/ca50ad52-05b2-4184-ac35-439c22262579.jpg
# fout : /tmp/bananas_fastai/train/yellow/BY3_na_22262579.jpg
# =============
# ofn : BY4.jpg
# ofn_root : BY4
# ofn_extention jpg
# augm : na
# newfile : BY4_na_37ce8903.jpg
# fin : /tmp/Bananas/802b5337-90e2-4521-9465-d7a337ce8903.jpg
# fout : /tmp/bananas_fastai/train/yellow/BY4_na_37ce8903.jpg
# =============
# ofn : BY25.jpg
# ofn_root : BY25
# ofn_extention jpg
# augm : na
# newfile : BY25_na_adc8eb64.jpg
# fin : /tmp/Bananas/e1a91059-d0ac-4ca0-9d52-3783adc8eb64.jpg
# fout : /tmp/bananas_fastai/train/yellow/BY25_na_adc8eb64.jpg
# =============
# ofn : BY9.jpg
# ofn_root : BY9
# ofn_extention jpg
# augm : na
# newfile : BY9_na_cff2d19d.jpg
# fin : /tmp/Bananas/e4901fbd-2505-46b6-96ac-6889cff2d19d.jpg
# fout : /tmp/bananas_fastai/train/yellow/BY9_na_cff2d19d.jpg
# =============
# ofn : BY27.jpg
# ofn_root : BY27
# ofn_extention jpg
# augm : na
# newfile : BY27_na_018c4885.jpg
# fin : /tmp/Bananas/05df2f49-b768-4041-9cdc-cb6f018c4885.jpg
# fout : /tmp/bananas_fastai/train/yellow/BY27_na_018c4885.jpg
# =============
# ofn : BY10.jpg
# ofn_root : BY10
# ofn_extention jpg
# augm : na
# newfile : BY10_na_5588b1e6.jpg
# fin : /tmp/Bananas/8a8989b5-3f61-46d1-943a-4ed85588b1e6.jpg
# fout : /tmp/bananas_fastai/train/yellow/BY10_na_5588b1e6.jpg
# =============
# ofn : BY30.jpg
# ofn_root : BY30
# ofn_extention jpg
# augm : na
# newfile : BY30_na_8799eef6.jpg
# fin : /tmp/Bananas/a300f601-6962-4629-87e3-9d278799eef6.jpg
# fout : /tmp/bananas_fastai/train/yellow/BY30_na_8799eef6.jpg
# =============
# ofn : BY14.jpg
# ofn_root : BY14
# ofn_extention jpg
# augm : na
# newfile : BY14_na_81176200.jpg
# fin : /tmp/Bananas/38e7fc0b-db8a-4a4f-877d-ef9e81176200.jpg
# fout : /tmp/bananas_fastai/train/yellow/BY14_na_81176200.jpg
# =============
# ofn : RP125.jpg
# ofn_root : RP125
# ofn_extention jpg
# augm : na
# newfile : RP125_na_54071214.jpg
# fin : /tmp/Bananas/e914c4de-0ad7-4933-915f-66b954071214.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP125_na_54071214.jpg
# =============
# ofn : BY31.jpg
# ofn_root : BY31
# ofn_extention jpg
# augm : na
# newfile : BY31_na_fc63a671.jpg
# fin : /tmp/Bananas/2cb0e07b-dcd9-4465-8201-a719fc63a671.jpg
# fout : /tmp/bananas_fastai/train/yellow/BY31_na_fc63a671.jpg
# =============
# ofn : BL6.jpg
# ofn_root : BL6
# ofn_extention jpg
# augm : na
# newfile : BL6_na_b52a3afd.jpg
# fin : /tmp/Bananas/f19f3381-b350-47f3-b1b4-5d79b52a3afd.jpg
# fout : /tmp/bananas_fastai/train/black/BL6_na_b52a3afd.jpg
# =============
# ofn : BL8.jpg
# ofn_root : BL8
# ofn_extention jpg
# augm : na
# newfile : BL8_na_d02cddfa.jpg
# fin : /tmp/Bananas/aa570949-1b26-4fbf-b5ca-a418d02cddfa.jpg
# fout : /tmp/bananas_fastai/train/black/BL8_na_d02cddfa.jpg
# =============
# ofn : RP51.jpg
# ofn_root : RP51
# ofn_extention jpg
# augm : na
# newfile : RP51_na_8d0ec95b.jpg
# fin : /tmp/Bananas/6ae348a1-6fc7-49a8-a5ea-37488d0ec95b.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP51_na_8d0ec95b.jpg
# =============
# ofn : BY16.jpg
# ofn_root : BY16
# ofn_extention jpg
# augm : na
# newfile : BY16_na_e08f1898.jpg
# fin : /tmp/Bananas/bcd443ee-f1a7-4623-9dd6-f49ee08f1898.jpg
# fout : /tmp/bananas_fastai/train/yellow/BY16_na_e08f1898.jpg
# =============
# ofn : BY35.jpg
# ofn_root : BY35
# ofn_extention jpg
# augm : na
# newfile : BY35_na_6db05d48.jpg
# fin : /tmp/Bananas/deca90e3-d3a7-4c4f-93e9-02a96db05d48.jpg
# fout : /tmp/bananas_fastai/train/yellow/BY35_na_6db05d48.jpg
# =============
# ofn : OR2.jpg
# ofn_root : OR2
# ofn_extention jpg
# augm : na
# newfile : OR2_na_a3ee7fd2.jpg
# fin : /tmp/Bananas/4f093042-0e23-4e8f-8d08-4197a3ee7fd2.jpg
# fout : /tmp/bananas_fastai/train/overripe/OR2_na_a3ee7fd2.jpg
# =============
# ofn : OR21.jpg
# ofn_root : OR21
# ofn_extention jpg
# augm : na
# newfile : OR21_na_d9894bff.jpg
# fin : /tmp/Bananas/11b85ae9-3559-4242-85bd-a240d9894bff.jpg
# fout : /tmp/bananas_fastai/train/overripe/OR21_na_d9894bff.jpg
# =============
# ofn : RP83.jpg
# ofn_root : RP83
# ofn_extention jpg
# augm : na
# newfile : RP83_na_c68c9f7d.jpg
# fin : /tmp/Bananas/f61404e1-e4e3-4b84-9e17-4d02c68c9f7d.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP83_na_c68c9f7d.jpg
# =============
# ofn : BL9.jpg
# ofn_root : BL9
# ofn_extention jpg
# augm : na
# newfile : BL9_na_12fc011f.jpg
# fin : /tmp/Bananas/734e3f95-03f9-4c9b-b602-828e12fc011f.jpg
# fout : /tmp/bananas_fastai/train/black/BL9_na_12fc011f.jpg
# =============
# ofn : OR22.jpg
# ofn_root : OR22
# ofn_extention jpg
# augm : na
# newfile : OR22_na_c70dda9b.jpg
# fin : /tmp/Bananas/0c46d62e-b9cb-4a80-83b0-3db2c70dda9b.jpg
# fout : /tmp/bananas_fastai/train/overripe/OR22_na_c70dda9b.jpg
# =============
# ofn : RP85.jpg
# ofn_root : RP85
# ofn_extention jpg
# augm : na
# newfile : RP85_na_ff509886.jpg
# fin : /tmp/Bananas/6c8baf99-ad06-43f7-9be1-994aff509886.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP85_na_ff509886.jpg
# =============
# ofn : RP52.jpg
# ofn_root : RP52
# ofn_extention jpg
# augm : na
# newfile : RP52_na_432a105d.jpg
# fin : /tmp/Bananas/76fc0a7d-fae2-4098-980c-aef5432a105d.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP52_na_432a105d.jpg
# =============
# ofn : BY21.jpg
# ofn_root : BY21
# ofn_extention jpg
# augm : na
# newfile : BY21_na_15a35e50.jpg
# fin : /tmp/Bananas/d4a7a7c4-848c-4457-b4ac-a6ee15a35e50.jpg
# fout : /tmp/bananas_fastai/train/yellow/BY21_na_15a35e50.jpg
# =============
# ofn : BY38.jpg
# ofn_root : BY38
# ofn_extention jpg
# augm : na
# newfile : BY38_na_a929d07f.jpg
# fin : /tmp/Bananas/be18f944-9d1c-41a4-ba3e-ae62a929d07f.jpg
# fout : /tmp/bananas_fastai/train/yellow/BY38_na_a929d07f.jpg
# =============
# ofn : OR5.jpg
# ofn_root : OR5
# ofn_extention jpg
# augm : na
# newfile : OR5_na_a97080ae.jpg
# fin : /tmp/Bananas/e91f3891-6659-4a6d-bfca-910ea97080ae.jpg
# fout : /tmp/bananas_fastai/train/overripe/OR5_na_a97080ae.jpg
# =============
# ofn : BL11.jpg
# ofn_root : BL11
# ofn_extention jpg
# augm : na
# newfile : BL11_na_d493daee.jpg
# fin : /tmp/Bananas/be45cf38-5de8-42b8-9634-f012d493daee.jpg
# fout : /tmp/bananas_fastai/train/black/BL11_na_d493daee.jpg
# =============
# ofn : G2.jpg
# ofn_root : G2
# ofn_extention jpg
# augm : na
# newfile : G2_na_d3a9b22c.jpg
# fin : /tmp/Bananas/1927b8e0-df5d-45ac-9d94-1bced3a9b22c.jpg
# fout : /tmp/bananas_fastai/train/green/G2_na_d3a9b22c.jpg
# =============
# ofn : RP86.jpg
# ofn_root : RP86
# ofn_extention jpg
# augm : na
# newfile : RP86_na_636bafbc.jpg
# fin : /tmp/Bananas/fc638d87-d7d1-45b4-b629-2ac0636bafbc.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP86_na_636bafbc.jpg
# =============
# ofn : BY40.jpg
# ofn_root : BY40
# ofn_extention jpg
# augm : na
# newfile : BY40_na_46c47d33.jpg
# fin : /tmp/Bananas/5d61e6f2-1b37-4ea0-9721-655846c47d33.jpg
# fout : /tmp/bananas_fastai/train/yellow/BY40_na_46c47d33.jpg
# =============
# ofn : BL12.jpg
# ofn_root : BL12
# ofn_extention jpg
# augm : na
# newfile : BL12_na_2d7f00f1.jpg
# fin : /tmp/Bananas/14511c8c-c4f2-4ac6-91f1-9c672d7f00f1.jpg
# fout : /tmp/bananas_fastai/train/black/BL12_na_2d7f00f1.jpg
# =============
# ofn : RP109.jpg
# ofn_root : RP109
# ofn_extention jpg
# augm : na
# newfile : RP109_na_a98fb3d9.jpg
# fin : /tmp/Bananas/ad371efb-7dec-4564-b718-b698a98fb3d9.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP109_na_a98fb3d9.jpg
# =============
# ofn : G6.jpg
# ofn_root : G6
# ofn_extention jpg
# augm : na
# newfile : G6_na_ee229116.jpg
# fin : /tmp/Bananas/41e3da71-0f1a-4ee6-8d71-8d25ee229116.jpg
# fout : /tmp/bananas_fastai/train/green/G6_na_ee229116.jpg
# =============
# ofn : RP91.jpg
# ofn_root : RP91
# ofn_extention jpg
# augm : na
# newfile : RP91_na_d511fed7.jpg
# fin : /tmp/Bananas/b4942267-b824-441e-baf3-e72cd511fed7.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP91_na_d511fed7.jpg
# =============
# ofn : BY41.jpg
# ofn_root : BY41
# ofn_extention jpg
# augm : na
# newfile : BY41_na_b41169fc.jpg
# fin : /tmp/Bananas/d98737ea-b7a1-4f20-b14d-d9a5b41169fc.jpg
# fout : /tmp/bananas_fastai/train/yellow/BY41_na_b41169fc.jpg
# =============
# ofn : BY22.jpg
# ofn_root : BY22
# ofn_extention jpg
# augm : na
# newfile : BY22_na_2ad62018.jpg
# fin : /tmp/Bananas/d2384635-4df0-4003-92ab-c98c2ad62018.jpg
# fout : /tmp/bananas_fastai/train/yellow/BY22_na_2ad62018.jpg
# =============
# ofn : RP55.jpg
# ofn_root : RP55
# ofn_extention jpg
# augm : na
# newfile : RP55_na_b40a4a44.jpg
# fin : /tmp/Bananas/76bd5270-554f-4f6c-8226-4e8eb40a4a44.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP55_na_b40a4a44.jpg
# =============
# ofn : OR9.jpg
# ofn_root : OR9
# ofn_extention jpg
# augm : na
# newfile : OR9_na_4c487288.jpg
# fin : /tmp/Bananas/a68a0ad1-1374-4d08-b3eb-60b84c487288.jpg
# fout : /tmp/bananas_fastai/train/overripe/OR9_na_4c487288.jpg
# =============
# ofn : BY43.jpg
# ofn_root : BY43
# ofn_extention jpg
# augm : na
# newfile : BY43_na_e9d1ec22.jpg
# fin : /tmp/Bananas/9ccbb746-8185-4b36-b755-d574e9d1ec22.jpg
# fout : /tmp/bananas_fastai/train/yellow/BY43_na_e9d1ec22.jpg
# =============
# ofn : G9.jpg
# ofn_root : G9
# ofn_extention jpg
# augm : na
# newfile : G9_na_99473f13.jpg
# fin : /tmp/Bananas/b23d840c-77f4-4ac9-a3ea-926e99473f13.jpg
# fout : /tmp/bananas_fastai/train/green/G9_na_99473f13.jpg
# =============
# ofn : G26.jpg
# ofn_root : G26
# ofn_extention jpg
# augm : na
# newfile : G26_na_2a552983.jpg
# fin : /tmp/Bananas/529e1422-2355-45ab-851d-19fa2a552983.jpg
# fout : /tmp/bananas_fastai/train/green/G26_na_2a552983.jpg
# =============
# ofn : BL13.jpg
# ofn_root : BL13
# ofn_extention jpg
# augm : na
# newfile : BL13_na_b7ecd5d0.jpg
# fin : /tmp/Bananas/6451c527-2644-4d6b-879f-5b61b7ecd5d0.jpg
# fout : /tmp/bananas_fastai/train/black/BL13_na_b7ecd5d0.jpg
# =============
# ofn : RP97.jpg
# ofn_root : RP97
# ofn_extention jpg
# augm : na
# newfile : RP97_na_ad307d9b.jpg
# fin : /tmp/Bananas/bbc38b36-1545-4a0d-a040-c8f1ad307d9b.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP97_na_ad307d9b.jpg
# =============
# ofn : RP1.jpg
# ofn_root : RP1
# ofn_extention jpg
# augm : na
# newfile : RP1_na_47aac57a.jpg
# fin : /tmp/Bananas/aca8609a-020d-416d-9057-001b47aac57a.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP1_na_47aac57a.jpg
# =============
# ofn : G27.jpg
# ofn_root : G27
# ofn_extention jpg
# augm : na
# newfile : G27_na_3b4b5eef.jpg
# fin : /tmp/Bananas/2a2a5745-9a8b-4baa-b101-77143b4b5eef.jpg
# fout : /tmp/bananas_fastai/train/green/G27_na_3b4b5eef.jpg
# =============
# ofn : RP111.jpg
# ofn_root : RP111
# ofn_extention jpg
# augm : na
# newfile : RP111_na_e0589b04.jpg
# fin : /tmp/Bananas/a459f1b7-8ada-4a77-8fe4-1618e0589b04.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP111_na_e0589b04.jpg
# =============
# ofn : RP29.jpg
# ofn_root : RP29
# ofn_extention jpg
# augm : na
# newfile : RP29_na_25ba68c8.jpg
# fin : /tmp/Bananas/ae7ffdcd-47a5-41ea-9a69-f0e925ba68c8.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP29_na_25ba68c8.jpg
# =============
# ofn : RP59.jpg
# ofn_root : RP59
# ofn_extention jpg
# augm : na
# newfile : RP59_na_f93211ff.jpg
# fin : /tmp/Bananas/6229cfde-23ac-4fbe-ba38-9115f93211ff.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP59_na_f93211ff.jpg
# =============
# ofn : G45.jpg
# ofn_root : G45
# ofn_extention jpg
# augm : na
# newfile : G45_na_f6e66b23.jpg
# fin : /tmp/Bananas/fc32ac31-a8f3-4b24-ab99-c4e2f6e66b23.jpg
# fout : /tmp/bananas_fastai/train/green/G45_na_f6e66b23.jpg
# =============
# ofn : OR11.jpg
# ofn_root : OR11
# ofn_extention jpg
# augm : na
# newfile : OR11_na_48d51728.jpg
# fin : /tmp/Bananas/d99d752c-d128-4c88-b796-0c5148d51728.jpg
# fout : /tmp/bananas_fastai/train/overripe/OR11_na_48d51728.jpg
# =============
# ofn : G29.jpg
# ofn_root : G29
# ofn_extention jpg
# augm : na
# newfile : G29_na_5fda6005.jpg
# fin : /tmp/Bananas/ad89cfa0-b513-45a8-b347-59355fda6005.jpg
# fout : /tmp/bananas_fastai/train/green/G29_na_5fda6005.jpg
# =============
# ofn : RP31.jpg
# ofn_root : RP31
# ofn_extention jpg
# augm : na
# newfile : RP31_na_2ba7ffe5.jpg
# fin : /tmp/Bananas/24e199a7-c8f4-4dbd-8b36-18fb2ba7ffe5.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP31_na_2ba7ffe5.jpg
# =============
# ofn : G46.jpg
# ofn_root : G46
# ofn_extention jpg
# augm : na
# newfile : G46_na_6272969b.jpg
# fin : /tmp/Bananas/a7e4f754-7c88-4568-8e06-422f6272969b.jpg
# fout : /tmp/bananas_fastai/train/green/G46_na_6272969b.jpg
# =============
# ofn : RP113.jpg
# ofn_root : RP113
# ofn_extention jpg
# augm : na
# newfile : RP113_na_58e25019.jpg
# fin : /tmp/Bananas/701a402d-2fef-4a73-ba05-7b9458e25019.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP113_na_58e25019.jpg
# =============
# ofn : RP34.jpg
# ofn_root : RP34
# ofn_extention jpg
# augm : na
# newfile : RP34_na_a020e954.jpg
# fin : /tmp/Bananas/ba28ae7b-5367-412e-b854-0b34a020e954.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP34_na_a020e954.jpg
# =============
# ofn : G50.jpg
# ofn_root : G50
# ofn_extention jpg
# augm : na
# newfile : G50_na_27ab73ff.jpg
# fin : /tmp/Bananas/98607fa3-4383-4f70-a124-0a2f27ab73ff.jpg
# fout : /tmp/bananas_fastai/train/green/G50_na_27ab73ff.jpg
# =============
# ofn : G10.jpg
# ofn_root : G10
# ofn_extention jpg
# augm : na
# newfile : G10_na_a49720e0.jpg
# fin : /tmp/Bananas/f63d1b5c-fedd-47b6-9270-cbfba49720e0.jpg
# fout : /tmp/bananas_fastai/train/green/G10_na_a49720e0.jpg
# =============
# ofn : RP98.jpg
# ofn_root : RP98
# ofn_extention jpg
# augm : na
# newfile : RP98_na_a494ac89.jpg
# fin : /tmp/Bananas/5b064e20-30bf-4db8-b41c-0033a494ac89.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP98_na_a494ac89.jpg
# =============
# ofn : G32.jpg
# ofn_root : G32
# ofn_extention jpg
# augm : na
# newfile : G32_na_e04fd4b6.jpg
# fin : /tmp/Bananas/dcc755b3-e521-4c6b-a55c-9fede04fd4b6.jpg
# fout : /tmp/bananas_fastai/train/green/G32_na_e04fd4b6.jpg
# =============
# ofn : BL15.jpg
# ofn_root : BL15
# ofn_extention jpg
# augm : na
# newfile : BL15_na_f165dd75.jpg
# fin : /tmp/Bananas/5210c565-96bf-4fa1-a2cf-c6ebf165dd75.jpg
# fout : /tmp/bananas_fastai/train/black/BL15_na_f165dd75.jpg
# =============
# ofn : RP114.jpg
# ofn_root : RP114
# ofn_extention jpg
# augm : na
# newfile : RP114_na_e1ecbbd0.jpg
# fin : /tmp/Bananas/cc53a2b7-22f7-4da4-a8eb-ff2de1ecbbd0.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP114_na_e1ecbbd0.jpg
# =============
# ofn : RP60.jpg
# ofn_root : RP60
# ofn_extention jpg
# augm : na
# newfile : RP60_na_ec6e08ee.jpg
# fin : /tmp/Bananas/b3227854-ff74-447a-99ce-bcafec6e08ee.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP60_na_ec6e08ee.jpg
# =============
# ofn : G51.jpg
# ofn_root : G51
# ofn_extention jpg
# augm : na
# newfile : G51_na_d873e648.jpg
# fin : /tmp/Bananas/0a36eefa-7748-4362-9c03-c5ebd873e648.jpg
# fout : /tmp/bananas_fastai/train/green/G51_na_d873e648.jpg
# =============
# ofn : RP36.jpg
# ofn_root : RP36
# ofn_extention jpg
# augm : na
# newfile : RP36_na_74c10b95.jpg
# fin : /tmp/Bananas/61ea9a3e-2b52-458a-8e89-5e0c74c10b95.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP36_na_74c10b95.jpg
# =============
# ofn : OR13.jpg
# ofn_root : OR13
# ofn_extention jpg
# augm : na
# newfile : OR13_na_423eef99.jpg
# fin : /tmp/Bananas/45cdb999-7d64-4f00-8818-9744423eef99.jpg
# fout : /tmp/bananas_fastai/train/overripe/OR13_na_423eef99.jpg
# =============
# ofn : G33.jpg
# ofn_root : G33
# ofn_extention jpg
# augm : na
# newfile : G33_na_19896d7f.jpg
# fin : /tmp/Bananas/ac146c9e-8658-43e8-a624-a94d19896d7f.jpg
# fout : /tmp/bananas_fastai/train/green/G33_na_19896d7f.jpg
# =============
# ofn : RP115.jpg
# ofn_root : RP115
# ofn_extention jpg
# augm : na
# newfile : RP115_na_d06cb4ad.jpg
# fin : /tmp/Bananas/c898903d-a1a9-4637-8f8f-3c32d06cb4ad.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP115_na_d06cb4ad.jpg
# =============
# ofn : G53.jpg
# ofn_root : G53
# ofn_extention jpg
# augm : na
# newfile : G53_na_2fbe03c3.jpg
# fin : /tmp/Bananas/ccd7783a-a2e4-49b4-8985-90f82fbe03c3.jpg
# fout : /tmp/bananas_fastai/train/green/G53_na_2fbe03c3.jpg
# =============
# ofn : RP37.jpg
# ofn_root : RP37
# ofn_extention jpg
# augm : na
# newfile : RP37_na_b4f9ac0c.jpg
# fin : /tmp/Bananas/f2f84b0d-1ba1-449b-8e37-aabbb4f9ac0c.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP37_na_b4f9ac0c.jpg
# =============
# ofn : G54.jpg
# ofn_root : G54
# ofn_extention jpg
# augm : na
# newfile : G54_na_5a3f6bb5.jpg
# fin : /tmp/Bananas/017948c4-8c01-45cf-a770-a3c75a3f6bb5.jpg
# fout : /tmp/bananas_fastai/train/green/G54_na_5a3f6bb5.jpg
# =============
# ofn : G34.jpg
# ofn_root : G34
# ofn_extention jpg
# augm : na
# newfile : G34_na_f202f0ed.jpg
# fin : /tmp/Bananas/3f562bc9-6144-4c26-a2e4-0d93f202f0ed.jpg
# fout : /tmp/bananas_fastai/train/green/G34_na_f202f0ed.jpg
# =============
# ofn : RP116.jpg
# ofn_root : RP116
# ofn_extention jpg
# augm : na
# newfile : RP116_na_a9cf2d15.jpg
# fin : /tmp/Bananas/f456efa9-4703-4e39-ab19-f3cea9cf2d15.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP116_na_a9cf2d15.jpg
# =============
# ofn : RP38.jpg
# ofn_root : RP38
# ofn_extention jpg
# augm : na
# newfile : RP38_na_46806ed2.jpg
# fin : /tmp/Bananas/ec1f6a1d-a711-4cdc-a07a-d9aa46806ed2.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP38_na_46806ed2.jpg
# =============
# ofn : RP22.jpg
# ofn_root : RP22
# ofn_extention jpg
# augm : na
# newfile : RP22_na_242ed521.jpg
# fin : /tmp/Bananas/21867579-1a13-46c9-91c5-5b90242ed521.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP22_na_242ed521.jpg
# =============
# ofn : RP67.jpg
# ofn_root : RP67
# ofn_extention jpg
# augm : na
# newfile : RP67_na_ce0d23af.jpg
# fin : /tmp/Bananas/a0df58c7-15a8-471d-95e4-9675ce0d23af.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP67_na_ce0d23af.jpg
# =============
# ofn : G11.jpg
# ofn_root : G11
# ofn_extention jpg
# augm : na
# newfile : G11_na_26ed01ec.jpg
# fin : /tmp/Bananas/5830daac-9f03-451b-97b9-69e426ed01ec.jpg
# fout : /tmp/bananas_fastai/train/green/G11_na_26ed01ec.jpg
# =============
# ofn : BL17.jpg
# ofn_root : BL17
# ofn_extention jpg
# augm : na
# newfile : BL17_na_0372a90a.jpg
# fin : /tmp/Bananas/276179b3-c1df-4779-a694-35170372a90a.jpg
# fout : /tmp/bananas_fastai/train/black/BL17_na_0372a90a.jpg
# =============
# ofn : RP100.jpg
# ofn_root : RP100
# ofn_extention jpg
# augm : na
# newfile : RP100_na_5588285f.jpg
# fin : /tmp/Bananas/9f2791a1-f8d4-4346-bd42-6c415588285f.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP100_na_5588285f.jpg
# =============
# ofn : OR14.jpg
# ofn_root : OR14
# ofn_extention jpg
# augm : na
# newfile : OR14_na_0d7d6ae2.jpg
# fin : /tmp/Bananas/a366d8c0-a03b-4ed8-a768-e48f0d7d6ae2.jpg
# fout : /tmp/bananas_fastai/train/overripe/OR14_na_0d7d6ae2.jpg
# =============
# ofn : G56.jpg
# ofn_root : G56
# ofn_extention jpg
# augm : na
# newfile : G56_na_9f1135ee.jpg
# fin : /tmp/Bananas/6630eb82-253f-45a2-8940-4ee09f1135ee.jpg
# fout : /tmp/bananas_fastai/train/green/G56_na_9f1135ee.jpg
# =============
# ofn : G37.jpg
# ofn_root : G37
# ofn_extention jpg
# augm : na
# newfile : G37_na_3fcef930.jpg
# fin : /tmp/Bananas/6fd11ea7-70df-4964-aced-55de3fcef930.jpg
# fout : /tmp/bananas_fastai/train/green/G37_na_3fcef930.jpg
# =============
# ofn : RP120.jpg
# ofn_root : RP120
# ofn_extention jpg
# augm : na
# newfile : RP120_na_6209361a.jpg
# fin : /tmp/Bananas/cfb830ed-2dc2-4610-963a-f2076209361a.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP120_na_6209361a.jpg
# =============
# ofn : G59.jpg
# ofn_root : G59
# ofn_extention jpg
# augm : na
# newfile : G59_na_17567c41.jpg
# fin : /tmp/Bananas/22293fd2-71a3-41bc-af76-ee2b17567c41.jpg
# fout : /tmp/bananas_fastai/train/green/G59_na_17567c41.jpg
# =============
# ofn : RP42.jpg
# ofn_root : RP42
# ofn_extention jpg
# augm : na
# newfile : RP42_na_b39a1e66.jpg
# fin : /tmp/Bananas/b8cae979-8adc-4536-8cef-66b8b39a1e66.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP42_na_b39a1e66.jpg
# =============
# ofn : G19.jpg
# ofn_root : G19
# ofn_extention jpg
# augm : na
# newfile : G19_na_ffcb8a2f.jpg
# fin : /tmp/Bananas/1c1b999d-6f13-4713-b7e5-481cffcb8a2f.jpg
# fout : /tmp/bananas_fastai/train/green/G19_na_ffcb8a2f.jpg
# =============
# ofn : RP23.jpg
# ofn_root : RP23
# ofn_extention jpg
# augm : na
# newfile : RP23_na_482246c5.jpg
# fin : /tmp/Bananas/2908dbe7-869e-4535-bab4-d9f7482246c5.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP23_na_482246c5.jpg
# =============
# ofn : RP73.jpg
# ofn_root : RP73
# ofn_extention jpg
# augm : na
# newfile : RP73_na_cb38a92b.jpg
# fin : /tmp/Bananas/2c00f88d-6250-43f1-85e9-ab91cb38a92b.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP73_na_cb38a92b.jpg
# =============
# ofn : BL18.jpg
# ofn_root : BL18
# ofn_extention jpg
# augm : na
# newfile : BL18_na_f77d1b25.jpg
# fin : /tmp/Bananas/5b428263-6938-4b51-9793-d427f77d1b25.jpg
# fout : /tmp/bananas_fastai/train/black/BL18_na_f77d1b25.jpg
# =============
# ofn : OR15.jpg
# ofn_root : OR15
# ofn_extention jpg
# augm : na
# newfile : OR15_na_22b4f553.jpg
# fin : /tmp/Bananas/fd7e46b1-ad39-4da0-9ffe-5e2022b4f553.jpg
# fout : /tmp/bananas_fastai/train/overripe/OR15_na_22b4f553.jpg
# =============
# ofn : RP102.jpg
# ofn_root : RP102
# ofn_extention jpg
# augm : na
# newfile : RP102_na_73f976a5.jpg
# fin : /tmp/Bananas/f54e9c50-eea7-44f1-8567-568d73f976a5.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP102_na_73f976a5.jpg
# =============
# ofn : G38.jpg
# ofn_root : G38
# ofn_extention jpg
# augm : na
# newfile : G38_na_bb1aa3ef.jpg
# fin : /tmp/Bananas/e05418a0-2120-4e74-82ff-7316bb1aa3ef.jpg
# fout : /tmp/bananas_fastai/train/green/G38_na_bb1aa3ef.jpg
# =============
# ofn : G23.jpg
# ofn_root : G23
# ofn_extention jpg
# augm : na
# newfile : G23_na_64acd987.jpg
# fin : /tmp/Bananas/588b766e-5484-4b19-a397-ce9264acd987.jpg
# fout : /tmp/bananas_fastai/train/green/G23_na_64acd987.jpg
# =============
# ofn : RP121.jpg
# ofn_root : RP121
# ofn_extention jpg
# augm : na
# newfile : RP121_na_b754b102.jpg
# fin : /tmp/Bananas/fafa901c-25b7-406e-a9c7-14d3b754b102.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP121_na_b754b102.jpg
# =============
# ofn : BL2.jpg
# ofn_root : BL2
# ofn_extention jpg
# augm : na
# newfile : BL2_na_e6f021ab.jpg
# fin : /tmp/Bananas/9d14e99f-60d4-4b5f-8d52-467ce6f021ab.jpg
# fout : /tmp/bananas_fastai/train/black/BL2_na_e6f021ab.jpg
# =============
# ofn : RP43.jpg
# ofn_root : RP43
# ofn_extention jpg
# augm : na
# newfile : RP43_na_2c4e3ced.jpg
# fin : /tmp/Bananas/74a32706-7f5d-4f44-9401-10662c4e3ced.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP43_na_2c4e3ced.jpg
# =============
# ofn : RP75.jpg
# ofn_root : RP75
# ofn_extention jpg
# augm : na
# newfile : RP75_na_331b91ed.jpg
# fin : /tmp/Bananas/51b2fdc6-88ba-4c6d-90ba-489b331b91ed.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP75_na_331b91ed.jpg
# =============
# ofn : RP103.jpg
# ofn_root : RP103
# ofn_extention jpg
# augm : na
# newfile : RP103_na_bcf38e96.jpg
# fin : /tmp/Bananas/c7b45a97-ddf4-43d4-91c3-2a5fbcf38e96.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP103_na_bcf38e96.jpg
# =============
# ofn : OR18.jpg
# ofn_root : OR18
# ofn_extention jpg
# augm : na
# newfile : OR18_na_b33127d7.jpg
# fin : /tmp/Bananas/8c7c25eb-b4d4-45e3-a091-6e87b33127d7.jpg
# fout : /tmp/bananas_fastai/train/overripe/OR18_na_b33127d7.jpg
# =============
# ofn : RP27.jpg
# ofn_root : RP27
# ofn_extention jpg
# augm : na
# newfile : RP27_na_4fa96b94.jpg
# fin : /tmp/Bananas/e5b5b747-0603-4671-8509-f0fd4fa96b94.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP27_na_4fa96b94.jpg
# =============
# ofn : G39.jpg
# ofn_root : G39
# ofn_extention jpg
# augm : na
# newfile : G39_na_3377a6f7.jpg
# fin : /tmp/Bananas/73fa3c61-8546-44b3-8b1b-9da43377a6f7.jpg
# fout : /tmp/bananas_fastai/train/green/G39_na_3377a6f7.jpg
# =============
# ofn : RP45.jpg
# ofn_root : RP45
# ofn_extention jpg
# augm : na
# newfile : RP45_na_a0bb95be.jpg
# fin : /tmp/Bananas/dd79a87a-d3de-4f47-b51f-b73da0bb95be.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP45_na_a0bb95be.jpg
# =============
# ofn : RP77.jpg
# ofn_root : RP77
# ofn_extention jpg
# augm : na
# newfile : RP77_na_4b57e3b9.jpg
# fin : /tmp/Bananas/5027b01f-3a1a-43f3-a3e4-ea264b57e3b9.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP77_na_4b57e3b9.jpg
# =============
# ofn : RP122.jpg
# ofn_root : RP122
# ofn_extention jpg
# augm : na
# newfile : RP122_na_e16074d2.jpg
# fin : /tmp/Bananas/c488f5af-8362-49e1-909a-2827e16074d2.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP122_na_e16074d2.jpg
# =============
# ofn : BL20.jpg
# ofn_root : BL20
# ofn_extention jpg
# augm : na
# newfile : BL20_na_39134322.jpg
# fin : /tmp/Bananas/d56bab27-fb17-4296-9697-466439134322.jpg
# fout : /tmp/bananas_fastai/train/black/BL20_na_39134322.jpg
# =============
# ofn : BL3.jpg
# ofn_root : BL3
# ofn_extention jpg
# augm : na
# newfile : BL3_na_d209b4fb.jpg
# fin : /tmp/Bananas/a3a69e58-2afa-4e64-ad62-16f1d209b4fb.jpg
# fout : /tmp/bananas_fastai/train/black/BL3_na_d209b4fb.jpg
# =============
# ofn : G24.jpg
# ofn_root : G24
# ofn_extention jpg
# augm : na
# newfile : G24_na_710e923c.jpg
# fin : /tmp/Bananas/e11979b2-d1b9-48f8-81ab-32a1710e923c.jpg
# fout : /tmp/bananas_fastai/train/green/G24_na_710e923c.jpg
# =============
# ofn : G41.jpg
# ofn_root : G41
# ofn_extention jpg
# augm : na
# newfile : G41_na_b3f4e4b3.jpg
# fin : /tmp/Bananas/137afd8e-d7fa-4d70-b1f8-5c4cb3f4e4b3.jpg
# fout : /tmp/bananas_fastai/train/green/G41_na_b3f4e4b3.jpg
# =============
# ofn : RP47.jpg
# ofn_root : RP47
# ofn_extention jpg
# augm : na
# newfile : RP47_na_fb02c94f.jpg
# fin : /tmp/Bananas/2159c80c-ca89-44a3-a9e7-f0ecfb02c94f.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP47_na_fb02c94f.jpg
# =============
# ofn : RP106.jpg
# ofn_root : RP106
# ofn_extention jpg
# augm : na
# newfile : RP106_na_7f3f75f6.jpg
# fin : /tmp/Bananas/be35b43d-6c54-4efe-97bb-54317f3f75f6.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP106_na_7f3f75f6.jpg
# =============
# ofn : RP79.jpg
# ofn_root : RP79
# ofn_extention jpg
# augm : na
# newfile : RP79_na_50a3b4d4.jpg
# fin : /tmp/Bananas/812bc319-69cb-4d59-8423-5fed50a3b4d4.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP79_na_50a3b4d4.jpg
# =============
# ofn : RP123.jpg
# ofn_root : RP123
# ofn_extention jpg
# augm : na
# newfile : RP123_na_14b58e77.jpg
# fin : /tmp/Bananas/68f4f3f5-5c05-435f-831b-9a2b14b58e77.jpg
# fout : /tmp/bananas_fastai/train/ripe/RP123_na_14b58e77.jpg
# =============
# ofn : OR19.jpg
# ofn_root : OR19
# ofn_extention jpg
# augm : na
# newfile : OR19_na_faa1a843.jpg
# fin : /tmp/Bananas/cbf0d798-8230-4ebf-a6f4-99b7faa1a843.jpg
# fout : /tmp/bananas_fastai/train/overripe/OR19_na_faa1a843.jpg
# =============

# %%
# !ls /tmp/bananas_fastai/train
# Out:
# black  green  overripe	ripe  yellow

# %%
# New project config!
mycfg = {
    "image_dir" : "/tmp/bananas_fastai",
    "classes":["black","green","overripe","yellow","ripe"],  ## <<- CLASS Enter your search terms here 
    "d_partitions":["train"],
}
ivicfg=getconfig(mycfg)
# Out:
# **getconfig** : Overriding Config image_dir:./class_images with /tmp/bananas_fastai
# **getconfig** : Overriding Config classes:['cars', 'busses', 'trucks'] with ['black', 'green', 'overripe', 'yellow', 'ripe']
# **getconfig** : Overriding Config d_partitions:['train', 'valid', 'test'] with ['train']

# %%
# New Image Path ..
path = Path(ivicfg["image_dir"])
path
# Out:
# PosixPath('/tmp/bananas_fastai')

# %%
# !ls /tmp/bananas_fastai/black
# Out:
# ls: cannot access /tmp/bananas_fastai/black: No such file or directory

# %% [markdown]
# ## Define Databunch

# %%
# Define some transforms and setup data bunch
tfms = get_transforms(do_flip=True,flip_vert=True,max_rotate=30)
data = ImageDataBunch.from_folder(path,train="train", ds_tfms=tfms, size=100, valid_pct=0.20)
data
# Out:
# ImageDataBunch;
#
# Train: LabelList (95 items)
# x: ImageList
# Image (3, 100, 100),Image (3, 100, 100),Image (3, 100, 100),Image (3, 100, 100),Image (3, 100, 100)
# y: CategoryList
# ripe,ripe,ripe,ripe,ripe
# Path: /tmp/bananas_fastai;
#
# Valid: LabelList (23 items)
# x: ImageList
# Image (3, 100, 100),Image (3, 100, 100),Image (3, 100, 100),Image (3, 100, 100),Image (3, 100, 100)
# y: CategoryList
# ripe,green,black,black,ripe
# Path: /tmp/bananas_fastai;
#
# Test: None

# %%
# Display some images
data.show_batch(rows=3, figsize=(5,5))

# %% [markdown]
# ## Training

# %%
# Setup a CNN learner
learn = cnn_learner(data, models.resnet50, metrics=accuracy)
learn.fit_one_cycle(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.856680</td>
#       <td>2.501822</td>
#       <td>0.217391</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.898064</td>
#       <td>2.720636</td>
#       <td>0.347826</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.275486</td>
#       <td>3.545374</td>
#       <td>0.217391</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.851732</td>
#       <td>3.549322</td>
#       <td>0.347826</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.628984</td>
#       <td>2.915265</td>
#       <td>0.434783</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Learning rate search
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='88' class='' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       88.00% [88/100 01:44<00:14]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.222640</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.883832</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.771692</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.771442</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.804702</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.786030</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.778231</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.774497</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.806456</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.865364</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.858427</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.831562</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.820678</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.820519</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.817765</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.806019</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.793502</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.803990</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.787031</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.778581</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.795978</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.781176</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.770305</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.792175</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.802980</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.795764</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.779202</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.785087</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.790995</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.795147</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.792128</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.807795</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.802791</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.794479</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.801126</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.792597</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.783053</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.781688</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.773726</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.771127</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.754275</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.753004</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.738367</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.725579</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.718104</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.702951</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.700239</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.679910</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.664241</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.648078</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.630662</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.617682</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.601575</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.585183</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.574669</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.562059</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.555470</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.543723</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.535428</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.530466</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.524431</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>0.512836</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.512553</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>0.501467</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.488870</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.480865</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>0.471549</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>0.461623</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>0.457168</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>0.448374</td>
#       <td>#na#</td>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Traceback (most recent call last):
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/multiprocessing/queues.py", line 232, in _feed
#     close()
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/multiprocessing/connection.py", line 177, in close
#     self._close()
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/multiprocessing/connection.py", line 361, in _close
#     _close(self._handle)
# OSError: [Errno 9] Bad file descriptor
# Traceback (most recent call last):
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/multiprocessing/queues.py", line 232, in _feed
#     close()
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/multiprocessing/connection.py", line 177, in close
#     self._close()
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/multiprocessing/connection.py", line 361, in _close
#     _close(self._handle)
# OSError: [Errno 9] Bad file descriptor
# Traceback (most recent call last):
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/multiprocessing/queues.py", line 232, in _feed
#     close()
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/multiprocessing/connection.py", line 177, in close
#     self._close()
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/multiprocessing/connection.py", line 361, in _close
#     _close(self._handle)
# OSError: [Errno 9] Bad file descriptor
# Traceback (most recent call last):
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/multiprocessing/queues.py", line 232, in _feed
#     close()
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/multiprocessing/connection.py", line 177, in close
#     self._close()
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/multiprocessing/connection.py", line 361, in _close
#     _close(self._handle)
# OSError: [Errno 9] Bad file descriptor
# Traceback (most recent call last):
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/multiprocessing/queues.py", line 232, in _feed
#     close()
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/multiprocessing/connection.py", line 177, in close
#     self._close()
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/multiprocessing/connection.py", line 361, in _close
#     _close(self._handle)
# OSError: [Errno 9] Bad file descriptor
# Traceback (most recent call last):
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/multiprocessing/queues.py", line 232, in _feed
#     close()
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/multiprocessing/connection.py", line 177, in close
#     self._close()
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/multiprocessing/connection.py", line 361, in _close
#     _close(self._handle)
# OSError: [Errno 9] Bad file descriptor
# Traceback (most recent call last):
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/multiprocessing/queues.py", line 232, in _feed
#     close()
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/multiprocessing/connection.py", line 177, in close
#     self._close()
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/multiprocessing/connection.py", line 361, in _close
#     _close(self._handle)
# OSError: [Errno 9] Bad file descriptor
# Traceback (most recent call last):
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/multiprocessing/queues.py", line 232, in _feed
#     close()
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/multiprocessing/connection.py", line 177, in close
#     self._close()
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/multiprocessing/connection.py", line 361, in _close
#     _close(self._handle)
# OSError: [Errno 9] Bad file descriptor
# Traceback (most recent call last):
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/multiprocessing/queues.py", line 232, in _feed
#     close()
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/multiprocessing/connection.py", line 177, in close
#     self._close()
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/multiprocessing/connection.py", line 361, in _close
#     _close(self._handle)
# OSError: [Errno 9] Bad file descriptor
# Traceback (most recent call last):
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/multiprocessing/queues.py", line 232, in _feed
#     close()
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/multiprocessing/connection.py", line 177, in close
#     self._close()
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/multiprocessing/connection.py", line 361, in _close
#     _close(self._handle)
# OSError: [Errno 9] Bad file descriptor
# Traceback (most recent call last):
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/multiprocessing/queues.py", line 232, in _feed
#     close()
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/multiprocessing/connection.py", line 177, in close
#     self._close()
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/multiprocessing/connection.py", line 361, in _close
#     _close(self._handle)
# OSError: [Errno 9] Bad file descriptor
# Traceback (most recent call last):
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/multiprocessing/queues.py", line 242, in _feed
#     send_bytes(obj)
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# OSError: [Errno 9] Bad file descriptor
# Traceback (most recent call last):
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/multiprocessing/queues.py", line 232, in _feed
#     close()
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/multiprocessing/connection.py", line 177, in close
#     self._close()
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/multiprocessing/connection.py", line 361, in _close
#     _close(self._handle)
# OSError: [Errno 9] Bad file descriptor
# Traceback (most recent call last):
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/multiprocessing/queues.py", line 232, in _feed
#     close()
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/multiprocessing/connection.py", line 177, in close
#     self._close()
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/multiprocessing/connection.py", line 361, in _close
#     _close(self._handle)
# OSError: [Errno 9] Bad file descriptor
# Exception in thread QueueFeederThread:
# Traceback (most recent call last):
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/multiprocessing/queues.py", line 232, in _feed
#     close()
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/multiprocessing/connection.py", line 177, in close
#     self._close()
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/multiprocessing/connection.py", line 361, in _close
#     _close(self._handle)
# OSError: [Errno 9] Bad file descriptor
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/multiprocessing/queues.py", line 263, in _feed
#     queue_sem.release()
# ValueError: semaphore or lock released too many times

# %%
learn.recorder.plot()

# %%
# Run fit one cycle for 5 epochs
learn.fit_one_cycle(5,slice(1e-4,2e-2))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.638852</td>
#       <td>2.745281</td>
#       <td>0.521739</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.627187</td>
#       <td>5.199791</td>
#       <td>0.565217</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.582000</td>
#       <td>5.805121</td>
#       <td>0.608696</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.518403</td>
#       <td>4.640246</td>
#       <td>0.652174</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.460146</td>
#       <td>3.513994</td>
#       <td>0.739130</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.fit_one_cycle(15,slice(1e-4,2e-2))
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='10' class='' max='15' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       66.67% [10/15 00:16<00:08]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.174612</td>
#       <td>1.579801</td>
#       <td>0.739130</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.224846</td>
#       <td>1.477074</td>
#       <td>0.782609</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.199341</td>
#       <td>1.408990</td>
#       <td>0.782609</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.243610</td>
#       <td>1.333543</td>
#       <td>0.826087</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.235913</td>
#       <td>1.321504</td>
#       <td>0.826087</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.222056</td>
#       <td>1.164511</td>
#       <td>0.869565</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.208647</td>
#       <td>1.153161</td>
#       <td>0.869565</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.184900</td>
#       <td>1.223545</td>
#       <td>0.869565</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.182495</td>
#       <td>1.246161</td>
#       <td>0.869565</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.177263</td>
#       <td>1.262027</td>
#       <td>0.826087</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# Exception ignored in: <function _releaseLock at 0x7fff950bfef0>
# Traceback (most recent call last):
#   File "/home/cecuser/anaconda3/envs/powerai-fastai/lib/python3.7/logging/__init__.py", line 221, in _releaseLock
#     def _releaseLock():
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# Empty                                     Traceback (most recent call last)
# ~/anaconda3/envs/powerai-fastai/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#     723         try:
# --> 724             data = self._data_queue.get(timeout=timeout)
#     725             return (True, data)
#
# ~/anaconda3/envs/powerai-fastai/lib/python3.7/queue.py in get(self, block, timeout)
#     177                     if remaining <= 0.0:
# --> 178                         raise Empty
#     179                     self.not_empty.wait(remaining)
#
# Empty:
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-65-fa197cc2a517> in <module>
# ----> 1 learn.fit_one_cycle(15,slice(1e-4,2e-2))
#
# ~/anaconda3/envs/powerai-fastai/lib/python3.7/site-packages/fastai/train.py in fit_one_cycle(learn, cyc_len, max_lr, moms, div_factor, pct_start, final_div, wd, callbacks, tot_epochs, start_epoch)
#      21     callbacks.append(OneCycleScheduler(learn, max_lr, moms=moms, div_factor=div_factor, pct_start=pct_start,
#      22                                        final_div=final_div, tot_epochs=tot_epochs, start_epoch=start_epoch))
# ---> 23     learn.fit(cyc_len, max_lr, wd=wd, callbacks=callbacks)
#      24
#      25 def fit_fc(learn:Learner, tot_epochs:int=1, lr:float=defaults.lr,  moms:Tuple[float,float]=(0.95,0.85), start_pct:float=0.72,
#
# ~/anaconda3/envs/powerai-fastai/lib/python3.7/site-packages/fastai/basic_train.py in fit(self, epochs, lr, wd, callbacks)
#     198         else: self.opt.lr,self.opt.wd = lr,wd
#     199         callbacks = [cb(self) for cb in self.callback_fns + listify(defaults.extra_callback_fns)] + listify(callbacks)
# --> 200         fit(epochs, self, metrics=self.metrics, callbacks=self.callbacks+callbacks)
#     201
#     202     def create_opt(self, lr:Floats, wd:Floats=0.)->None:
#
# ~/anaconda3/envs/powerai-fastai/lib/python3.7/site-packages/fastai/basic_train.py in fit(epochs, learn, callbacks, metrics)
#     104             if not cb_handler.skip_validate and not learn.data.empty_val:
#     105                 val_loss = validate(learn.model, learn.data.valid_dl, loss_func=learn.loss_func,
# --> 106                                        cb_handler=cb_handler, pbar=pbar)
#     107             else: val_loss=None
#     108             if cb_handler.on_epoch_end(val_loss): break
#
# ~/anaconda3/envs/powerai-fastai/lib/python3.7/site-packages/fastai/basic_train.py in validate(model, dl, loss_func, cb_handler, pbar, average, n_batch)
#      55         val_losses,nums = [],[]
#      56         if cb_handler: cb_handler.set_dl(dl)
# ---> 57         for xb,yb in progress_bar(dl, parent=pbar, leave=(pbar is not None)):
#      58             if cb_handler: xb, yb = cb_handler.on_batch_begin(xb, yb, train=False)
#      59             val_loss = loss_batch(model, xb, yb, loss_func, cb_handler=cb_handler)
#
# ~/anaconda3/envs/powerai-fastai/lib/python3.7/site-packages/fastprogress/fastprogress.py in __iter__(self)
#      45         except Exception as e:
#      46             self.on_interrupt()
# ---> 47             raise e
#      48
#      49     def update(self, val):
#
# ~/anaconda3/envs/powerai-fastai/lib/python3.7/site-packages/fastprogress/fastprogress.py in __iter__(self)
#      39         if self.total != 0: self.update(0)
#      40         try:
# ---> 41             for i,o in enumerate(self.gen):
#      42                 if i >= self.total: break
#      43                 yield o
#
# ~/anaconda3/envs/powerai-fastai/lib/python3.7/site-packages/fastai/basic_data.py in __iter__(self)
#      73     def __iter__(self):
#      74         "Process and returns items from `DataLoader`."
# ---> 75         for b in self.dl: yield self.proc_batch(b)
#      76
#      77     @classmethod
#
# ~/anaconda3/envs/powerai-fastai/lib/python3.7/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     802
#     803             assert not self._shutdown and self._tasks_outstanding > 0
# --> 804             idx, data = self._get_data()
#     805             self._tasks_outstanding -= 1
#     806
#
# ~/anaconda3/envs/powerai-fastai/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _get_data(self)
#     759         elif self._pin_memory:
#     760             while self._pin_memory_thread.is_alive():
# --> 761                 success, data = self._try_get_data()
#     762                 if success:
#     763                     return data
#
# ~/anaconda3/envs/powerai-fastai/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#     735             if len(failed_workers) > 0:
#     736                 pids_str = ', '.join(str(w.pid) for w in failed_workers)
# --> 737                 raise RuntimeError('DataLoader worker (pid(s) {}) exited unexpectedly'.format(pids_str))
#     738             if isinstance(e, queue.Empty):
#     739                 return (False, None)
#
# RuntimeError: DataLoader worker (pid(s) 31956, 31957, 31958, 31959) exited unexpectedly

# %%
learn.save('banana-78')

# %%
learn.load('banana-78')
learn.fit_one_cycle(20,slice(1e-4,2e-2))
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='8' class='' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       40.00% [8/20 00:13<00:20]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.054309</td>
#       <td>1.288626</td>
#       <td>0.826087</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.127744</td>
#       <td>1.328989</td>
#       <td>0.826087</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.110849</td>
#       <td>1.366997</td>
#       <td>0.826087</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.116823</td>
#       <td>1.395888</td>
#       <td>0.826087</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.097513</td>
#       <td>1.438385</td>
#       <td>0.869565</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.085862</td>
#       <td>1.504704</td>
#       <td>0.869565</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.097143</td>
#       <td>1.582753</td>
#       <td>0.869565</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.085358</td>
#       <td>1.661908</td>
#       <td>0.869565</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-67-3adabcbc93f5> in <module>
#       1 learn.load('banana-78')
# ----> 2 learn.fit_one_cycle(20,slice(1e-4,2e-2))
#
# ~/anaconda3/envs/powerai-fastai/lib/python3.7/site-packages/fastai/train.py in fit_one_cycle(learn, cyc_len, max_lr, moms, div_factor, pct_start, final_div, wd, callbacks, tot_epochs, start_epoch)
#      21     callbacks.append(OneCycleScheduler(learn, max_lr, moms=moms, div_factor=div_factor, pct_start=pct_start,
#      22                                        final_div=final_div, tot_epochs=tot_epochs, start_epoch=start_epoch))
# ---> 23     learn.fit(cyc_len, max_lr, wd=wd, callbacks=callbacks)
#      24
#      25 def fit_fc(learn:Learner, tot_epochs:int=1, lr:float=defaults.lr,  moms:Tuple[float,float]=(0.95,0.85), start_pct:float=0.72,
#
# ~/anaconda3/envs/powerai-fastai/lib/python3.7/site-packages/fastai/basic_train.py in fit(self, epochs, lr, wd, callbacks)
#     198         else: self.opt.lr,self.opt.wd = lr,wd
#     199         callbacks = [cb(self) for cb in self.callback_fns + listify(defaults.extra_callback_fns)] + listify(callbacks)
# --> 200         fit(epochs, self, metrics=self.metrics, callbacks=self.callbacks+callbacks)
#     201
#     202     def create_opt(self, lr:Floats, wd:Floats=0.)->None:
#
# ~/anaconda3/envs/powerai-fastai/lib/python3.7/site-packages/fastai/basic_train.py in fit(epochs, learn, callbacks, metrics)
#      97             cb_handler.set_dl(learn.data.train_dl)
#      98             cb_handler.on_epoch_begin()
# ---> 99             for xb,yb in progress_bar(learn.data.train_dl, parent=pbar):
#     100                 xb, yb = cb_handler.on_batch_begin(xb, yb)
#     101                 loss = loss_batch(learn.model, xb, yb, learn.loss_func, learn.opt, cb_handler)
#
# ~/anaconda3/envs/powerai-fastai/lib/python3.7/site-packages/fastprogress/fastprogress.py in __iter__(self)
#      39         if self.total != 0: self.update(0)
#      40         try:
# ---> 41             for i,o in enumerate(self.gen):
#      42                 if i >= self.total: break
#      43                 yield o
#
# ~/anaconda3/envs/powerai-fastai/lib/python3.7/site-packages/fastai/basic_data.py in __iter__(self)
#      73     def __iter__(self):
#      74         "Process and returns items from `DataLoader`."
# ---> 75         for b in self.dl: yield self.proc_batch(b)
#      76
#      77     @classmethod
#
# ~/anaconda3/envs/powerai-fastai/lib/python3.7/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     802
#     803             assert not self._shutdown and self._tasks_outstanding > 0
# --> 804             idx, data = self._get_data()
#     805             self._tasks_outstanding -= 1
#     806
#
# ~/anaconda3/envs/powerai-fastai/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _get_data(self)
#     759         elif self._pin_memory:
#     760             while self._pin_memory_thread.is_alive():
# --> 761                 success, data = self._try_get_data()
#     762                 if success:
#     763                     return data
#
# ~/anaconda3/envs/powerai-fastai/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#     722         #   (bool: whether successfully get data, any: data if successful else None)
#     723         try:
# --> 724             data = self._data_queue.get(timeout=timeout)
#     725             return (True, data)
#     726         except Exception as e:
#
# ~/anaconda3/envs/powerai-fastai/lib/python3.7/queue.py in get(self, block, timeout)
#     177                     if remaining <= 0.0:
#     178                         raise Empty
# --> 179                     self.not_empty.wait(remaining)
#     180             item = self._get()
#     181             self.not_full.notify()
#
# ~/anaconda3/envs/powerai-fastai/lib/python3.7/threading.py in wait(self, timeout)
#     298             else:
#     299                 if timeout > 0:
# --> 300                     gotit = waiter.acquire(True, timeout)
#     301                 else:
#     302                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
# Lets see how well we did ... 
interp = ClassificationInterpretation.from_learner(learn)
losses,idxs = interp.top_losses()
len(data.valid_ds)==len(losses)==len(idxs)
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %% [markdown]
# # Inference

# %%
# Download some sample images here .... 
command = googliser + \
                      " --o /tmp/banana_inference "+\
                      " --phrase \"ripe black yellow green bananas\" " + \
                      " --parallel 50 --upper-size 500000 --lower-size 2000 " + \
                      " -n 10 " + \
                      " --format jpg --timeout 15 --safesearch-off "
print(command)
# !{command}
# Out:
# /home/cecuser/5050/aicoc-ai-immersion/FastAI/googliser/googliser.sh --o /tmp/banana_inference  --phrase "ripe black yellow green bananas"  --parallel 50 --upper-size 500000 --lower-size 2000  -n 10  --format jpg --timeout 15 --safesearch-off
#  googliser.sh v:200212 PID:431
#
#    Google: 0/10 web pages OK, 1/10 are in progres0/10 web pages OK, 2/10 are in progres0/10 web pages OK, 3/10 are in progres0/10 web pages OK, 4/10 are in progres0/10 web pages OK, 5/10 are in progres0/10 web pages OK, 6/10 are in progres0/10 web pages OK, 7/10 are in progres0/10 web pages OK, 8/10 are in progres0/10 web pages OK, 9/10 are in progres0/10 web pages OK, 10/10 are in progress10 web pages OK
#     links: 81
#  download: 0/10 images OK0/10 images OK, 1/50 are in progress0/10 images OK, 2/50 are in progress0/10 images OK, 3/50 are in progress0/10 images OK, 4/50 are in progress0/10 images OK, 5/50 are in progress0/10 images OK, 6/50 are in progress0/10 images OK, 7/50 are in progress0/10 images OK, 8/50 are in progress0/10 images OK, 9/50 are in progress0/10 images OK, 10/50 are in progres0/10 images OK, 11/50 are in progres0/10 images OK, 12/50 are in progres0/10 images OK, 13/50 are in progres0/10 images OK, 14/50 are in progres0/10 images OK, 15/50 are in progres0/10 images OK, 16/50 are in progres0/10 images OK, 17/50 are in progres0/10 images OK, 18/50 are in progres0/10 images OK, 19/50 are in progres0/10 images OK, 20/50 are in progres0/10 images OK, 21/50 are in progres0/10 images OK, 22/50 are in progres0/10 images OK, 22/50 are in progress and 1 have faile0/10 images OK, 23/50 are in progress and 1 have faile0/10 images OK, 24/50 are in progress and 1 have faile0/10 images OK, 25/50 are in progress and 1 have faile1/10 images OK, 25/50 are in progress and 2 have faile2/10 images OK, 25/50 are in progress and 2 have faile2/10 images OK, 26/50 are in progress and 2 have faile2/10 images OK, 27/50 are in progress and 2 have faile2/10 images OK, 28/50 are in progress and 3 have faile5/10 images OK, 26/50 are in progress and 4 have faile5/10 images OK, 24/50 are in progress and 5 have faile5/10 images OK, 25/50 are in progress and 5 have faile5/10 images OK, 25/50 are in progress and 6 have faile6/10 images OK, 25/50 are in progress and 6 have faile6/10 images OK, 26/50 are in progress and 6 have faile6/10 images OK, 27/50 are in progress and 6 have faile6/10 images OK, 28/50 are in progress and 6 have faile6/10 images OK, 29/50 are in progress and 6 have faile6/10 images OK, 30/50 are in progress and 6 have faile6/10 images OK, 31/50 are in progress and 6 have faile7/10 images OK, 32/50 are in progress and 6 have faile8/10 images OK, 31/50 are in progress and 6 have faile8/10 images OK, 32/50 are in progress and 6 have faile12/10 images OK, 28/50 are in progress and 8 have failed31/10 images OK and 14 failed                         10 images OK and 14 failed

# %%
# get rid of malformed images manually .

command = cfg["jpeginfo"] + " -c /tmp/banana_inference"
# !{command}

#!ls /tmp/banana_inference
#!rm /tmp/banana_inference/image\(0020\).jpg

# %%
# Inference on your list of images .. 
import glob
files = glob.glob("/tmp/banana_inference/image*.jpg")

def single_inference(img_path) :
    
    img = open_image(img_path)
    prediction=learn.predict(img)
    #print(prediction)
    img_cls = data.classes[prediction[1].numpy()]
    img.show(title=img_cls)

for my_img in files :
    single_inference(my_img)

# %% [markdown]
# Congratulations, you can now build a pretty darn good classifier in less than one hour!
#
# Credits
# * FastAI Team
# * Bob Chesebrough / Dustin VanStee - AICoC Data science team
